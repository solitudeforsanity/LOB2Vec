# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import sys
import tensorflow as tf
import time
from pylab import *
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer
from skimage.util.shape import view_as_windows
from sklearn.metrics import roc_curve,roc_auc_score
from tcn import TCN, tcn_full_summary
from tensorflow.keras.layers import Dense, Conv2D, Layer, Lambda, Flatten
from tensorflow.keras import Input, Model, metrics
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.python.client import device_lib

module_path = os.path.abspath(os.path.join('..'))
project_path = os.path.abspath(os.path.join('../..'))
train_source = os.path.abspath(os.path.join('../../data/train_source/'))
test_source = os.path.abspath(os.path.join('../../data/test_source/'))
train_path = os.path.abspath(os.path.join('../../data/train/'))
test_path = os.path.abspath(os.path.join('../../data/test/'))
dest_path_bsu = os.path.abspath(os.path.join('../../data/final_bsu/'))
dest_path_bs = os.path.abspath(os.path.join('../../data/final_bs/'))
val_path_bs = os.path.abspath(os.path.join('../../data/validation_bs/'))
val_path_bsu = os.path.abspath(os.path.join('../../data/validation_bsu/'))

if module_path not in sys.path:
    sys.path.append(module_path)
if project_path not in sys.path:
    sys.path.append(project_path)
    
np.set_printoptions(suppress=True)
np.set_printoptions(threshold=sys.maxsize)
#print(device_lib.list_local_devices())

# %%
# 1. Train 10 without weights 128 bs - DONE
# 2. Train 10 without weights 256 bs - DONE
# 3. Train 10 without weights 1024 bs - DONE
# 4. Train 10 weights 128 bs - DONE
# 5. Train 10 weights 256 bs - DONE
# 6. Train 10 weights 1024 bs - DONE
# 7. Train 10 without weights 128 bsu
# 8. Train 10 without weights 256 bsu
# 9. Train 10 without weights 1024 bsu
# 10. Train 10 weights 128 bsu
# 11. Train 10 weights 256 bsu
# 12. Train 10 weights 1024 bsu

---------------------------------------------

# 13. Train 50 without weights 128 bs - DONE
# 14. Train 50 without weights 256 bs - RUNNING
# 15. Train 50 without weights 1024 bs
# 16. Train 50 weights 128 bs
# 17. Train 50 weights 256 bs
# 18. Train 50 weights 1024 bs
# 19. Train 50 without weights 128 bsu
# 20. Train 50 without weights 256 bsu
# 21. Train 50 without weights 1024 bsu
# 22. Train 50 weights 128 bsu
# 23. Train 50 weights 256 bsu
# 24. Train 50 weights 1024 bsu

# %%
# Hyperparameters
nb_classes=2
cols, rows = 2, 30
input_shape = (cols, rows, 1)
vol_imb_diff = 0.1
evaluate_every = 100 # interval for evaluating on one-shot tasks
batch_size = 32
n_iter = 20000 # No. of training iterations
n_val = 250 # how many one-shot tasks to validate on
h = 30
w = 2
d = 2

# %%
num_frames = 50
# FOR BS Training 
# Train
X_train = np.load(dest_path_bs + '/' + str(num_frames) + '_X_train.npy')
Y_train = np.load(dest_path_bs + '/' + str(num_frames) + '_Y_train.npy')
F_train = np.load(dest_path_bs + '/' + str(num_frames) + '_F_train.npy')
X_test = np.load(dest_path_bs + '/' + str(num_frames) + '_X_test.npy')
Y_test = np.load(dest_path_bs + '/' + str(num_frames) + '_Y_test.npy')
F_test = np.load(dest_path_bs + '/' + str(num_frames) + '_F_test.npy')

print(X_train.shape)
print(X_test.shape)

#X_train = np.append(X_train, X_test, axis=0)
#Y_train = np.append(Y_train, Y_test, axis=0)
#F_train = np.append(F_train, F_test, axis=0)
#print(X_train.shape)

# Validation
X_val = np.load(val_path_bs + '/' + str(num_frames) + '_X_val.npy')
Y_val = np.load(val_path_bs + '/' + str(num_frames) + '_Y_val.npy')
print(X_val.shape)
# Out:
# (53649, 50, 30, 2, 2)
# (19875, 50, 30, 2, 2)
# (178000, 50, 30, 2, 2)

# %%
# FOR BSU Training 
# Train
Xu_train = np.load(dest_path_bsu + '/' + str(num_frames) + '_X_train.npy')
Yu_train = np.load(dest_path_bsu + '/' + str(num_frames) + '_Y_train.npy')
Fu_train = np.load(dest_path_bsu + '/' + str(num_frames) + '_F_train.npy')
Xu_test = np.load(dest_path_bsu + '/' + str(num_frames) + '_X_test.npy')
Yu_test = np.load(dest_path_bsu + '/' + str(num_frames) + '_Y_test.npy')
Fu_test = np.load(dest_path_bsu + '/' + str(num_frames) + '_F_test.npy')

print(Xu_train.shape)
print(Xu_test.shape)

Xu_train = np.append(Xu_train, Xu_test, axis=0)
Yu_train = np.append(Yu_train, Yu_test, axis=0)
Fu_train = np.append(Fu_train, Fu_test, axis=0)
print(Xu_train.shape)

# Validation
Xu_val = np.load(val_path_bsu + '/' + str(num_frames) + '_X_val.npy')
Yu_val = np.load(val_path_bsu + '/' + str(num_frames) + '_Y_val.npy')

# %%
# COMBINE BS AND BSU
X_train = np.append(X_train, Xu_train, axis=0)
Y_train = np.append(Y_train, Yu_train, axis=0)
F_train = np.append(F_train, Fu_train, axis=0)
print(X_train.shape)

X_val = np.append(X_val, Xu_val, axis=0)
Y_val = np.append(Y_val, Yu_val, axis=0)
print(X_val.shape)

# %% [markdown]
# ### Model Initialisation

# %%
def initialize_weights(shape, name=None, dtype=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer weights with mean as 0.0 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

def initialize_bias(shape, name=None, dtype=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer bias with mean as 0.5 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# Intialize bias with mean 0.0 and standard deviation of 10^-2
weights = initialize_weights((1000,1))
sns.distplot(weights)
plt.title("Plot of weights initialized, with mean of 0.0 and standard deviation of 0.01")

# Intialize bias with mean 0.5 and standard deviation of 10^-2
bias = initialize_bias((1000,1))
sns.distplot(bias)
plt.title("Plot of biases initialized, with mean of 0.0 and standard deviation of 0.01")
# Out:
# Text(0.5, 1.0, 'Plot of biases initialized, with mean of 0.0 and standard deviation of 0.01')

# %%
class CategoricalTruePositives(tf.keras.metrics.Metric):
    def __init__(self, num_classes, batch_size,
                 name="categorical_true_positives", **kwargs):
        super(CategoricalTruePositives, self).__init__(name=name, **kwargs)

        self.batch_size = batch_size
        self.num_classes = num_classes    

        self.cat_true_positives = self.add_weight(name="ctp", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):     

        y_true = K.argmax(y_true, axis=-1)
        y_pred = K.argmax(y_pred, axis=-1)
        y_true = K.flatten(y_true)

        true_poss = K.sum(K.cast((K.equal(y_true, y_pred)), dtype=tf.float32))
        self.cat_true_positives.assign_add(true_poss)

    def result(self):
        return self.cat_true_positives

# %%
def embedding_model(frames, h, w, c, input_shape, dimensions, include_top=False, pooling=None, classes=1):  
    inp = Input(shape=(frames, h, w, c))
    out = Lambda(lambda y: K.reshape(y, (-1, h, w, c)))(inp)
    num_features_cnn = np.prod(K.int_shape(out)[1:])
    out = Lambda(lambda y: K.reshape(y, (-1, num_frames, num_features_cnn)))(inp)
    out = TCN(nb_filters=128, kernel_size=2, return_sequences=False, dilations=[1, 2, 4, 8, 16, 32, 64], 
              activation=tf.keras.activations.swish, nb_stacks=1, dropout_rate=0.08)(out)
    out = Flatten()(out)
    out = Dense(256, activation=None, kernel_regularizer=l2(1e-3), kernel_initializer='he_uniform')(out)    
    return Model(inputs=inp, outputs=out)

def triplets_model(input_shape, embedding, include_top=False, pooling=None):
    anchor_input = Input(shape=input_shape, name='anchor_input')
    encoded_a = embedding(anchor_input)
    prediction = Dense(nb_classes+1, activation='softmax',bias_initializer=initialize_bias)(encoded_a)
    triplet_net = Model(inputs=[anchor_input],outputs=[prediction])
    return triplet_net

build_embedding = embedding_model(num_frames, h, w, d, input_shape=(num_frames, h, w, d), dimensions=60)
build_triplet = triplets_model(input_shape=(num_frames, h, w, d), embedding=build_embedding)
optimizer = Adam(lr = 0.00006)
build_triplet.compile(loss=tf.keras.losses.CategoricalCrossentropy(),optimizer=optimizer, 
                      metrics=[metrics.MeanSquaredError(), tf.keras.metrics.Recall(), tf.keras.metrics.Precision(),
                      tf.keras.metrics.CategoricalAccuracy(name='acc'),
                      CategoricalTruePositives(nb_classes, batch_size)])
build_embedding.summary()
build_triplet.summary()
tcn_full_summary(build_embedding, expand_residual_blocks=True)
plot_model(build_embedding, 'multi_input_and_output_model.png', show_shapes=True)
# Out:
# Model: "model_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 50, 30, 2, 2)]    0
# _________________________________________________________________
# lambda_23 (Lambda)           (None, 50, 120)           0
# _________________________________________________________________
# tcn_11 (TCN)                 (None, 128)               473984
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               33024
# =================================================================
# Total params: 507,008
# Trainable params: 507,008
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# anchor_input (InputLayer)    [(None, 50, 30, 2, 2)]    0
# _________________________________________________________________
# model_22 (Model)             (None, 256)               507008
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 507,779
# Trainable params: 507,779
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 50, 30, 2, 2)]    0
# _________________________________________________________________
# lambda_23 (Lambda)           (None, 50, 120)           0
# _________________________________________________________________
# matching_conv1D (Conv1D)     (None, 50, 128)           15488
# _________________________________________________________________
# activation_233 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           30848
# _________________________________________________________________
# activation_231 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_154 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_232 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_155 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_236 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_234 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_156 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_235 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_157 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_239 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_237 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_158 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_238 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_159 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_242 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_240 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_160 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_241 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_161 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_245 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_243 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_162 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_244 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_163 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_248 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_246 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_164 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_247 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_165 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_251 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_249 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_166 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_250 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_167 (Spati (None, 50, 128)           0
# _________________________________________________________________
# lambda_11 (Lambda)           (None, 128)               0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               33024
# =================================================================
# Total params: 507,008
# Trainable params: 507,008
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training - 10 Frames

# %%
labels_train = K.one_hot(Y_train, nb_classes+1)
labels_val = K.one_hot(Y_val, nb_classes+1)
history = build_triplet.fit(x=X_train, y=labels_train, batch_size=batch_size, epochs=200, verbose=1, callbacks=None, 
                              validation_split=0.02, validation_data=None, shuffle=True, class_weight=None, 
                              sample_weight=None, initial_epoch=0, steps_per_epoch=50, validation_steps=None)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1533d892e050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1533d892e050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 50/50 [==============================] - ETA: 0s - loss: 36.0655 - mean_squared_error: 0.3129 - recall_25: 0.4006 - precision_25: 0.4748 - acc: 0.4881 - categorical_true_positives: 781.0000WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1533d85473b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1533d85473b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 50/50 [==============================] - 8s 167ms/step - loss: 36.0655 - mean_squared_error: 0.3129 - recall_25: 0.4006 - precision_25: 0.4748 - acc: 0.4881 - categorical_true_positives: 781.0000 - val_loss: 18.4440 - val_mean_squared_error: 0.3046 - val_recall_25: 0.5219 - val_precision_25: 0.5253 - val_acc: 0.5238 - val_categorical_true_positives: 562.0000
# Epoch 2/200
# 50/50 [==============================] - 7s 138ms/step - loss: 17.5103 - mean_squared_error: 0.2805 - recall_25: 0.4313 - precision_25: 0.5192 - acc: 0.5575 - categorical_true_positives: 892.0000 - val_loss: 26.8474 - val_mean_squared_error: 0.3420 - val_recall_25: 0.4641 - val_precision_25: 0.4689 - val_acc: 0.4678 - val_categorical_true_positives: 502.0000
# Epoch 3/200
# 50/50 [==============================] - 7s 139ms/step - loss: 17.5522 - mean_squared_error: 0.2701 - recall_25: 0.4325 - precision_25: 0.5307 - acc: 0.5725 - categorical_true_positives: 916.0000 - val_loss: 11.1855 - val_mean_squared_error: 0.2539 - val_recall_25: 0.5843 - val_precision_25: 0.5926 - val_acc: 0.5890 - val_categorical_true_positives: 632.0000
# Epoch 4/200
# 50/50 [==============================] - 7s 138ms/step - loss: 11.5908 - mean_squared_error: 0.2577 - recall_25: 0.4425 - precision_25: 0.5455 - acc: 0.5956 - categorical_true_positives: 953.0000 - val_loss: 10.5350 - val_mean_squared_error: 0.2370 - val_recall_25: 0.6095 - val_precision_25: 0.6193 - val_acc: 0.6170 - val_categorical_true_positives: 662.0000
# Epoch 5/200
# 50/50 [==============================] - 7s 138ms/step - loss: 11.1348 - mean_squared_error: 0.2603 - recall_25: 0.4469 - precision_25: 0.5396 - acc: 0.5775 - categorical_true_positives: 924.0000 - val_loss: 8.5318 - val_mean_squared_error: 0.2055 - val_recall_25: 0.6533 - val_precision_25: 0.6657 - val_acc: 0.6608 - val_categorical_true_positives: 709.0000
# Epoch 6/200
# 50/50 [==============================] - 7s 137ms/step - loss: 8.6606 - mean_squared_error: 0.2419 - recall_25: 0.4650 - precision_25: 0.5759 - acc: 0.6150 - categorical_true_positives: 984.0000 - val_loss: 7.4541 - val_mean_squared_error: 0.1971 - val_recall_25: 0.6673 - val_precision_25: 0.6819 - val_acc: 0.6757 - val_categorical_true_positives: 725.0000
# Epoch 7/200
# 50/50 [==============================] - 7s 137ms/step - loss: 8.4845 - mean_squared_error: 0.2311 - recall_25: 0.4762 - precision_25: 0.5962 - acc: 0.6306 - categorical_true_positives: 1009.0000 - val_loss: 6.7773 - val_mean_squared_error: 0.1887 - val_recall_25: 0.6757 - val_precision_25: 0.6911 - val_acc: 0.6859 - val_categorical_true_positives: 736.0000
# Epoch 8/200
# 50/50 [==============================] - 7s 139ms/step - loss: 7.3638 - mean_squared_error: 0.2224 - recall_25: 0.4719 - precision_25: 0.6016 - acc: 0.6413 - categorical_true_positives: 1026.0000 - val_loss: 6.0098 - val_mean_squared_error: 0.1772 - val_recall_25: 0.6906 - val_precision_25: 0.7064 - val_acc: 0.6990 - val_categorical_true_positives: 750.0000
# Epoch 9/200
# 50/50 [==============================] - 7s 137ms/step - loss: 6.6017 - mean_squared_error: 0.2232 - recall_25: 0.4700 - precision_25: 0.5997 - acc: 0.6463 - categorical_true_positives: 1034.0000 - val_loss: 6.0963 - val_mean_squared_error: 0.1748 - val_recall_25: 0.6934 - val_precision_25: 0.7092 - val_acc: 0.7055 - val_categorical_true_positives: 757.0000
# Epoch 10/200
# 50/50 [==============================] - 7s 137ms/step - loss: 5.9963 - mean_squared_error: 0.2027 - recall_25: 0.5150 - precision_25: 0.6463 - acc: 0.6794 - categorical_true_positives: 1087.0000 - val_loss: 5.6524 - val_mean_squared_error: 0.1602 - val_recall_25: 0.7195 - val_precision_25: 0.7373 - val_acc: 0.7297 - val_categorical_true_positives: 783.0000
# Epoch 11/200
# 50/50 [==============================] - 7s 142ms/step - loss: 5.6966 - mean_squared_error: 0.2013 - recall_25: 0.5131 - precision_25: 0.6500 - acc: 0.6750 - categorical_true_positives: 1080.0000 - val_loss: 4.5207 - val_mean_squared_error: 0.1489 - val_recall_25: 0.7344 - val_precision_25: 0.7526 - val_acc: 0.7437 - val_categorical_true_positives: 798.0000
# Epoch 12/200
# 50/50 [==============================] - 7s 142ms/step - loss: 4.3428 - mean_squared_error: 0.1820 - recall_25: 0.5319 - precision_25: 0.6733 - acc: 0.6963 - categorical_true_positives: 1114.0000 - val_loss: 4.4010 - val_mean_squared_error: 0.1547 - val_recall_25: 0.7251 - val_precision_25: 0.7445 - val_acc: 0.7363 - val_categorical_true_positives: 790.0000
# Epoch 13/200
# 50/50 [==============================] - 7s 141ms/step - loss: 5.1430 - mean_squared_error: 0.1901 - recall_25: 0.5156 - precision_25: 0.6589 - acc: 0.6875 - categorical_true_positives: 1100.0000 - val_loss: 6.7673 - val_mean_squared_error: 0.1748 - val_recall_25: 0.6915 - val_precision_25: 0.7107 - val_acc: 0.7036 - val_categorical_true_positives: 755.0000
# Epoch 14/200
# 50/50 [==============================] - 7s 136ms/step - loss: 4.1131 - mean_squared_error: 0.1831 - recall_25: 0.5138 - precision_25: 0.6667 - acc: 0.6906 - categorical_true_positives: 1105.0000 - val_loss: 4.0729 - val_mean_squared_error: 0.1509 - val_recall_25: 0.7325 - val_precision_25: 0.7479 - val_acc: 0.7409 - val_categorical_true_positives: 795.0000
# Epoch 15/200
# 50/50 [==============================] - 5s 105ms/step - loss: 4.1827 - mean_squared_error: 0.1782 - recall_25: 0.5444 - precision_25: 0.6805 - acc: 0.7025 - categorical_true_positives: 1124.0000 - val_loss: 6.0691 - val_mean_squared_error: 0.1650 - val_recall_25: 0.7111 - val_precision_25: 0.7308 - val_acc: 0.7223 - val_categorical_true_positives: 775.0000
# Epoch 16/200
# 50/50 [==============================] - 6s 111ms/step - loss: 4.2547 - mean_squared_error: 0.1791 - recall_25: 0.5656 - precision_25: 0.6851 - acc: 0.7075 - categorical_true_positives: 1132.0000 - val_loss: 4.5299 - val_mean_squared_error: 0.1516 - val_recall_25: 0.7316 - val_precision_25: 0.7434 - val_acc: 0.7353 - val_categorical_true_positives: 789.0000
# Epoch 17/200
# 50/50 [==============================] - 5s 107ms/step - loss: 4.1829 - mean_squared_error: 0.1730 - recall_25: 0.6137 - precision_25: 0.7055 - acc: 0.7050 - categorical_true_positives: 1128.0000 - val_loss: 3.7810 - val_mean_squared_error: 0.1371 - val_recall_25: 0.7521 - val_precision_25: 0.7635 - val_acc: 0.7558 - val_categorical_true_positives: 811.0000
# Epoch 18/200
# 50/50 [==============================] - 6s 112ms/step - loss: 3.0613 - mean_squared_error: 0.1645 - recall_25: 0.6925 - precision_25: 0.7266 - acc: 0.7225 - categorical_true_positives: 1156.0000 - val_loss: 3.6849 - val_mean_squared_error: 0.1294 - val_recall_25: 0.7661 - val_precision_25: 0.7711 - val_acc: 0.7689 - val_categorical_true_positives: 825.0000
# Epoch 19/200
# 50/50 [==============================] - 5s 106ms/step - loss: 3.8148 - mean_squared_error: 0.1612 - recall_25: 0.7100 - precision_25: 0.7245 - acc: 0.7212 - categorical_true_positives: 1154.0000 - val_loss: 3.6338 - val_mean_squared_error: 0.1307 - val_recall_25: 0.7661 - val_precision_25: 0.7689 - val_acc: 0.7661 - val_categorical_true_positives: 822.0000
# Epoch 20/200
# 50/50 [==============================] - 6s 112ms/step - loss: 3.1622 - mean_squared_error: 0.1462 - recall_25: 0.7450 - precision_25: 0.7559 - acc: 0.7525 - categorical_true_positives: 1204.0000 - val_loss: 4.1242 - val_mean_squared_error: 0.1415 - val_recall_25: 0.7474 - val_precision_25: 0.7516 - val_acc: 0.7502 - val_categorical_true_positives: 805.0000
# Epoch 21/200
# 50/50 [==============================] - 5s 106ms/step - loss: 3.3291 - mean_squared_error: 0.1595 - recall_25: 0.7219 - precision_25: 0.7292 - acc: 0.7256 - categorical_true_positives: 1161.0000 - val_loss: 3.7634 - val_mean_squared_error: 0.1283 - val_recall_25: 0.7707 - val_precision_25: 0.7751 - val_acc: 0.7745 - val_categorical_true_positives: 831.0000
# Epoch 22/200
# 50/50 [==============================] - 6s 113ms/step - loss: 3.3829 - mean_squared_error: 0.1506 - recall_25: 0.7319 - precision_25: 0.7411 - acc: 0.7381 - categorical_true_positives: 1181.0000 - val_loss: 3.5843 - val_mean_squared_error: 0.1267 - val_recall_25: 0.7782 - val_precision_25: 0.7811 - val_acc: 0.7801 - val_categorical_true_positives: 837.0000
# Epoch 23/200
# 50/50 [==============================] - 5s 105ms/step - loss: 3.0222 - mean_squared_error: 0.1548 - recall_25: 0.7231 - precision_25: 0.7309 - acc: 0.7262 - categorical_true_positives: 1162.0000 - val_loss: 4.5334 - val_mean_squared_error: 0.1393 - val_recall_25: 0.7577 - val_precision_25: 0.7612 - val_acc: 0.7605 - val_categorical_true_positives: 816.0000
# Epoch 24/200
# 50/50 [==============================] - 6s 112ms/step - loss: 2.8291 - mean_squared_error: 0.1532 - recall_25: 0.7131 - precision_25: 0.7272 - acc: 0.7237 - categorical_true_positives: 1158.0000 - val_loss: 3.5008 - val_mean_squared_error: 0.1207 - val_recall_25: 0.7866 - val_precision_25: 0.7895 - val_acc: 0.7875 - val_categorical_true_positives: 845.0000
# Epoch 25/200
# 50/50 [==============================] - 5s 105ms/step - loss: 2.7163 - mean_squared_error: 0.1470 - recall_25: 0.7369 - precision_25: 0.7410 - acc: 0.7387 - categorical_true_positives: 1182.0000 - val_loss: 3.6276 - val_mean_squared_error: 0.1253 - val_recall_25: 0.7791 - val_precision_25: 0.7820 - val_acc: 0.7791 - val_categorical_true_positives: 836.0000
# Epoch 26/200
# 50/50 [==============================] - 6s 113ms/step - loss: 2.4643 - mean_squared_error: 0.1315 - recall_25: 0.7725 - precision_25: 0.7774 - acc: 0.7756 - categorical_true_positives: 1241.0000 - val_loss: 3.2937 - val_mean_squared_error: 0.1217 - val_recall_25: 0.7838 - val_precision_25: 0.7852 - val_acc: 0.7838 - val_categorical_true_positives: 841.0000
# Epoch 27/200
# 50/50 [==============================] - 5s 107ms/step - loss: 2.6989 - mean_squared_error: 0.1370 - recall_25: 0.7575 - precision_25: 0.7608 - acc: 0.7600 - categorical_true_positives: 1216.0000 - val_loss: 4.1524 - val_mean_squared_error: 0.1317 - val_recall_25: 0.7633 - val_precision_25: 0.7654 - val_acc: 0.7633 - val_categorical_true_positives: 819.0000
# Epoch 28/200
# 50/50 [==============================] - 6s 112ms/step - loss: 2.9578 - mean_squared_error: 0.1429 - recall_25: 0.7437 - precision_25: 0.7494 - acc: 0.7462 - categorical_true_positives: 1194.0000 - val_loss: 3.1958 - val_mean_squared_error: 0.1225 - val_recall_25: 0.7866 - val_precision_25: 0.7866 - val_acc: 0.7866 - val_categorical_true_positives: 844.0000
# Epoch 29/200
# 50/50 [==============================] - 5s 106ms/step - loss: 2.6871 - mean_squared_error: 0.1419 - recall_25: 0.7481 - precision_25: 0.7519 - acc: 0.7500 - categorical_true_positives: 1200.0000 - val_loss: 2.9423 - val_mean_squared_error: 0.1141 - val_recall_25: 0.7950 - val_precision_25: 0.7965 - val_acc: 0.7950 - val_categorical_true_positives: 853.0000
# Epoch 30/200
# 50/50 [==============================] - 6s 113ms/step - loss: 2.2756 - mean_squared_error: 0.1342 - recall_25: 0.7581 - precision_25: 0.7619 - acc: 0.7600 - categorical_true_positives: 1216.0000 - val_loss: 2.8287 - val_mean_squared_error: 0.1168 - val_recall_25: 0.7884 - val_precision_25: 0.7899 - val_acc: 0.7884 - val_categorical_true_positives: 846.0000
# Epoch 31/200
# 50/50 [==============================] - 5s 106ms/step - loss: 2.4901 - mean_squared_error: 0.1418 - recall_25: 0.7369 - precision_25: 0.7396 - acc: 0.7381 - categorical_true_positives: 1181.0000 - val_loss: 2.8846 - val_mean_squared_error: 0.1188 - val_recall_25: 0.7894 - val_precision_25: 0.7946 - val_acc: 0.7912 - val_categorical_true_positives: 849.0000
# Epoch 32/200
# 50/50 [==============================] - 6s 113ms/step - loss: 2.4056 - mean_squared_error: 0.1380 - recall_25: 0.7462 - precision_25: 0.7486 - acc: 0.7487 - categorical_true_positives: 1198.0000 - val_loss: 3.0787 - val_mean_squared_error: 0.1140 - val_recall_25: 0.7940 - val_precision_25: 0.7985 - val_acc: 0.7940 - val_categorical_true_positives: 852.0000
# Epoch 33/200
# 50/50 [==============================] - 5s 106ms/step - loss: 2.1619 - mean_squared_error: 0.1372 - recall_25: 0.7381 - precision_25: 0.7418 - acc: 0.7400 - categorical_true_positives: 1184.0000 - val_loss: 3.5605 - val_mean_squared_error: 0.1217 - val_recall_25: 0.7810 - val_precision_25: 0.7854 - val_acc: 0.7829 - val_categorical_true_positives: 840.0000
# Epoch 34/200
# 50/50 [==============================] - 6s 114ms/step - loss: 1.9036 - mean_squared_error: 0.1262 - recall_25: 0.7713 - precision_25: 0.7732 - acc: 0.7731 - categorical_true_positives: 1237.0000 - val_loss: 2.7316 - val_mean_squared_error: 0.1100 - val_recall_25: 0.8015 - val_precision_25: 0.8037 - val_acc: 0.8015 - val_categorical_true_positives: 860.0000
# Epoch 35/200
# 50/50 [==============================] - 5s 106ms/step - loss: 1.9715 - mean_squared_error: 0.1176 - recall_25: 0.7925 - precision_25: 0.7945 - acc: 0.7931 - categorical_true_positives: 1269.0000 - val_loss: 2.6312 - val_mean_squared_error: 0.1124 - val_recall_25: 0.8006 - val_precision_25: 0.8013 - val_acc: 0.8006 - val_categorical_true_positives: 859.0000
# Epoch 36/200
# 50/50 [==============================] - 6s 112ms/step - loss: 2.3603 - mean_squared_error: 0.1385 - recall_25: 0.7406 - precision_25: 0.7425 - acc: 0.7419 - categorical_true_positives: 1187.0000 - val_loss: 4.4728 - val_mean_squared_error: 0.1307 - val_recall_25: 0.7689 - val_precision_25: 0.7710 - val_acc: 0.7689 - val_categorical_true_positives: 825.0000
# Epoch 37/200
# 50/50 [==============================] - 5s 108ms/step - loss: 2.2227 - mean_squared_error: 0.1298 - recall_25: 0.7631 - precision_25: 0.7655 - acc: 0.7650 - categorical_true_positives: 1224.0000 - val_loss: 2.5983 - val_mean_squared_error: 0.1107 - val_recall_25: 0.7978 - val_precision_25: 0.8007 - val_acc: 0.7987 - val_categorical_true_positives: 857.0000
# Epoch 38/200
# 50/50 [==============================] - 6s 113ms/step - loss: 1.9729 - mean_squared_error: 0.1256 - recall_25: 0.7631 - precision_25: 0.7655 - acc: 0.7631 - categorical_true_positives: 1221.0000 - val_loss: 2.4843 - val_mean_squared_error: 0.1058 - val_recall_25: 0.8052 - val_precision_25: 0.8082 - val_acc: 0.8071 - val_categorical_true_positives: 866.0000
# Epoch 39/200
# 50/50 [==============================] - 5s 104ms/step - loss: 1.9181 - mean_squared_error: 0.1205 - recall_25: 0.7800 - precision_25: 0.7834 - acc: 0.7812 - categorical_true_positives: 1250.0000 - val_loss: 2.5811 - val_mean_squared_error: 0.1009 - val_recall_25: 0.8136 - val_precision_25: 0.8182 - val_acc: 0.8145 - val_categorical_true_positives: 874.0000
# Epoch 40/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.8764 - mean_squared_error: 0.1183 - recall_25: 0.7738 - precision_25: 0.7757 - acc: 0.7750 - categorical_true_positives: 1240.0000 - val_loss: 2.2392 - val_mean_squared_error: 0.1099 - val_recall_25: 0.7959 - val_precision_25: 0.8004 - val_acc: 0.7978 - val_categorical_true_positives: 856.0000
# Epoch 41/200
# 50/50 [==============================] - 5s 105ms/step - loss: 1.8761 - mean_squared_error: 0.1197 - recall_25: 0.7738 - precision_25: 0.7752 - acc: 0.7744 - categorical_true_positives: 1239.0000 - val_loss: 2.1787 - val_mean_squared_error: 0.1022 - val_recall_25: 0.8089 - val_precision_25: 0.8143 - val_acc: 0.8127 - val_categorical_true_positives: 872.0000
# Epoch 42/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.9904 - mean_squared_error: 0.1222 - recall_25: 0.7763 - precision_25: 0.7777 - acc: 0.7769 - categorical_true_positives: 1243.0000 - val_loss: 2.0490 - val_mean_squared_error: 0.1010 - val_recall_25: 0.8052 - val_precision_25: 0.8105 - val_acc: 0.8071 - val_categorical_true_positives: 866.0000
# Epoch 43/200
# 50/50 [==============================] - 5s 106ms/step - loss: 1.9537 - mean_squared_error: 0.1186 - recall_25: 0.7706 - precision_25: 0.7735 - acc: 0.7725 - categorical_true_positives: 1236.0000 - val_loss: 3.3718 - val_mean_squared_error: 0.1115 - val_recall_25: 0.7968 - val_precision_25: 0.7998 - val_acc: 0.7987 - val_categorical_true_positives: 857.0000
# Epoch 44/200
# 50/50 [==============================] - 6s 113ms/step - loss: 1.8257 - mean_squared_error: 0.1205 - recall_25: 0.7769 - precision_25: 0.7774 - acc: 0.7769 - categorical_true_positives: 1243.0000 - val_loss: 3.2132 - val_mean_squared_error: 0.1088 - val_recall_25: 0.7987 - val_precision_25: 0.8024 - val_acc: 0.8006 - val_categorical_true_positives: 859.0000
# Epoch 45/200
# 50/50 [==============================] - 5s 106ms/step - loss: 1.7337 - mean_squared_error: 0.1127 - recall_25: 0.7812 - precision_25: 0.7837 - acc: 0.7819 - categorical_true_positives: 1251.0000 - val_loss: 1.8507 - val_mean_squared_error: 0.0964 - val_recall_25: 0.8229 - val_precision_25: 0.8237 - val_acc: 0.8229 - val_categorical_true_positives: 883.0000
# Epoch 46/200
# 50/50 [==============================] - 5s 110ms/step - loss: 1.5791 - mean_squared_error: 0.1035 - recall_25: 0.8012 - precision_25: 0.8043 - acc: 0.8031 - categorical_true_positives: 1285.0000 - val_loss: 1.9880 - val_mean_squared_error: 0.0941 - val_recall_25: 0.8285 - val_precision_25: 0.8308 - val_acc: 0.8285 - val_categorical_true_positives: 889.0000
# Epoch 47/200
# 50/50 [==============================] - 5s 109ms/step - loss: 1.7458 - mean_squared_error: 0.1097 - recall_25: 0.7887 - precision_25: 0.7897 - acc: 0.7887 - categorical_true_positives: 1262.0000 - val_loss: 1.7701 - val_mean_squared_error: 0.0942 - val_recall_25: 0.8229 - val_precision_25: 0.8245 - val_acc: 0.8229 - val_categorical_true_positives: 883.0000
# Epoch 48/200
# 50/50 [==============================] - 5s 110ms/step - loss: 1.6059 - mean_squared_error: 0.1050 - recall_25: 0.8031 - precision_25: 0.8036 - acc: 0.8031 - categorical_true_positives: 1285.0000 - val_loss: 1.7232 - val_mean_squared_error: 0.0939 - val_recall_25: 0.8248 - val_precision_25: 0.8256 - val_acc: 0.8248 - val_categorical_true_positives: 885.0000
# Epoch 49/200
# 50/50 [==============================] - 5s 110ms/step - loss: 1.5201 - mean_squared_error: 0.1171 - recall_25: 0.7719 - precision_25: 0.7733 - acc: 0.7719 - categorical_true_positives: 1235.0000 - val_loss: 2.2029 - val_mean_squared_error: 0.0939 - val_recall_25: 0.8257 - val_precision_25: 0.8288 - val_acc: 0.8285 - val_categorical_true_positives: 889.0000
# Epoch 50/200
# 50/50 [==============================] - 5s 109ms/step - loss: 1.7090 - mean_squared_error: 0.1134 - recall_25: 0.7775 - precision_25: 0.7790 - acc: 0.7788 - categorical_true_positives: 1246.0000 - val_loss: 2.2832 - val_mean_squared_error: 0.0952 - val_recall_25: 0.8248 - val_precision_25: 0.8263 - val_acc: 0.8257 - val_categorical_true_positives: 886.0000
# Epoch 51/200
# 50/50 [==============================] - 6s 111ms/step - loss: 1.5142 - mean_squared_error: 0.1067 - recall_25: 0.7850 - precision_25: 0.7865 - acc: 0.7862 - categorical_true_positives: 1258.0000 - val_loss: 1.9317 - val_mean_squared_error: 0.0910 - val_recall_25: 0.8350 - val_precision_25: 0.8374 - val_acc: 0.8360 - val_categorical_true_positives: 897.0000
# Epoch 52/200
# 50/50 [==============================] - 5s 107ms/step - loss: 1.5308 - mean_squared_error: 0.0969 - recall_25: 0.8225 - precision_25: 0.8240 - acc: 0.8231 - categorical_true_positives: 1317.0000 - val_loss: 1.7248 - val_mean_squared_error: 0.0883 - val_recall_25: 0.8350 - val_precision_25: 0.8382 - val_acc: 0.8369 - val_categorical_true_positives: 898.0000
# Epoch 53/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.3590 - mean_squared_error: 0.1015 - recall_25: 0.8050 - precision_25: 0.8055 - acc: 0.8056 - categorical_true_positives: 1289.0000 - val_loss: 2.4301 - val_mean_squared_error: 0.1007 - val_recall_25: 0.8117 - val_precision_25: 0.8140 - val_acc: 0.8127 - val_categorical_true_positives: 872.0000
# Epoch 54/200
# 50/50 [==============================] - 5s 105ms/step - loss: 1.5087 - mean_squared_error: 0.1014 - recall_25: 0.8012 - precision_25: 0.8023 - acc: 0.8012 - categorical_true_positives: 1282.0000 - val_loss: 1.5740 - val_mean_squared_error: 0.0864 - val_recall_25: 0.8369 - val_precision_25: 0.8393 - val_acc: 0.8369 - val_categorical_true_positives: 898.0000
# Epoch 55/200
# 50/50 [==============================] - 6s 113ms/step - loss: 1.4942 - mean_squared_error: 0.1096 - recall_25: 0.7925 - precision_25: 0.7935 - acc: 0.7925 - categorical_true_positives: 1268.0000 - val_loss: 1.5139 - val_mean_squared_error: 0.0830 - val_recall_25: 0.8388 - val_precision_25: 0.8411 - val_acc: 0.8397 - val_categorical_true_positives: 901.0000
# Epoch 56/200
# 50/50 [==============================] - 5s 105ms/step - loss: 1.3855 - mean_squared_error: 0.1015 - recall_25: 0.8075 - precision_25: 0.8090 - acc: 0.8081 - categorical_true_positives: 1293.0000 - val_loss: 1.9220 - val_mean_squared_error: 0.0936 - val_recall_25: 0.8257 - val_precision_25: 0.8280 - val_acc: 0.8267 - val_categorical_true_positives: 887.0000
# Epoch 57/200
# 50/50 [==============================] - 6s 113ms/step - loss: 1.4205 - mean_squared_error: 0.1011 - recall_25: 0.8069 - precision_25: 0.8074 - acc: 0.8069 - categorical_true_positives: 1291.0000 - val_loss: 1.4273 - val_mean_squared_error: 0.0795 - val_recall_25: 0.8425 - val_precision_25: 0.8449 - val_acc: 0.8434 - val_categorical_true_positives: 905.0000
# Epoch 58/200
# 50/50 [==============================] - 5s 109ms/step - loss: 1.5034 - mean_squared_error: 0.1133 - recall_25: 0.7731 - precision_25: 0.7736 - acc: 0.7738 - categorical_true_positives: 1238.0000 - val_loss: 1.4062 - val_mean_squared_error: 0.0766 - val_recall_25: 0.8490 - val_precision_25: 0.8506 - val_acc: 0.8509 - val_categorical_true_positives: 913.0000
# Epoch 59/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.3888 - mean_squared_error: 0.0996 - recall_25: 0.8000 - precision_25: 0.8015 - acc: 0.8000 - categorical_true_positives: 1280.0000 - val_loss: 1.5715 - val_mean_squared_error: 0.0823 - val_recall_25: 0.8444 - val_precision_25: 0.8451 - val_acc: 0.8444 - val_categorical_true_positives: 906.0000
# Epoch 60/200
# 50/50 [==============================] - 5s 106ms/step - loss: 1.2345 - mean_squared_error: 0.0884 - recall_25: 0.8294 - precision_25: 0.8320 - acc: 0.8306 - categorical_true_positives: 1329.0000 - val_loss: 2.1590 - val_mean_squared_error: 0.0955 - val_recall_25: 0.8229 - val_precision_25: 0.8252 - val_acc: 0.8239 - val_categorical_true_positives: 884.0000
# Epoch 61/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.4765 - mean_squared_error: 0.1086 - recall_25: 0.7869 - precision_25: 0.7879 - acc: 0.7869 - categorical_true_positives: 1259.0000 - val_loss: 1.4318 - val_mean_squared_error: 0.0774 - val_recall_25: 0.8546 - val_precision_25: 0.8570 - val_acc: 0.8555 - val_categorical_true_positives: 918.0000
# Epoch 62/200
# 50/50 [==============================] - 5s 107ms/step - loss: 1.2427 - mean_squared_error: 0.0997 - recall_25: 0.7987 - precision_25: 0.8003 - acc: 0.8006 - categorical_true_positives: 1281.0000 - val_loss: 1.4721 - val_mean_squared_error: 0.0760 - val_recall_25: 0.8518 - val_precision_25: 0.8534 - val_acc: 0.8527 - val_categorical_true_positives: 915.0000
# Epoch 63/200
# 50/50 [==============================] - 6s 114ms/step - loss: 1.2338 - mean_squared_error: 0.0922 - recall_25: 0.8188 - precision_25: 0.8208 - acc: 0.8194 - categorical_true_positives: 1311.0000 - val_loss: 1.5060 - val_mean_squared_error: 0.0756 - val_recall_25: 0.8574 - val_precision_25: 0.8598 - val_acc: 0.8574 - val_categorical_true_positives: 920.0000
# Epoch 64/200
# 50/50 [==============================] - 5s 107ms/step - loss: 1.2251 - mean_squared_error: 0.0916 - recall_25: 0.8188 - precision_25: 0.8198 - acc: 0.8194 - categorical_true_positives: 1311.0000 - val_loss: 1.3078 - val_mean_squared_error: 0.0731 - val_recall_25: 0.8537 - val_precision_25: 0.8553 - val_acc: 0.8537 - val_categorical_true_positives: 916.0000
# Epoch 65/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.2950 - mean_squared_error: 0.0927 - recall_25: 0.8100 - precision_25: 0.8115 - acc: 0.8112 - categorical_true_positives: 1298.0000 - val_loss: 1.2775 - val_mean_squared_error: 0.0710 - val_recall_25: 0.8602 - val_precision_25: 0.8634 - val_acc: 0.8602 - val_categorical_true_positives: 923.0000
# Epoch 66/200
# 50/50 [==============================] - 5s 107ms/step - loss: 1.2016 - mean_squared_error: 0.0911 - recall_25: 0.8181 - precision_25: 0.8186 - acc: 0.8188 - categorical_true_positives: 1310.0000 - val_loss: 1.2637 - val_mean_squared_error: 0.0720 - val_recall_25: 0.8602 - val_precision_25: 0.8626 - val_acc: 0.8611 - val_categorical_true_positives: 924.0000
# Epoch 67/200
# 50/50 [==============================] - 6s 118ms/step - loss: 1.2240 - mean_squared_error: 0.0985 - recall_25: 0.7987 - precision_25: 0.8003 - acc: 0.8000 - categorical_true_positives: 1280.0000 - val_loss: 1.7433 - val_mean_squared_error: 0.0813 - val_recall_25: 0.8453 - val_precision_25: 0.8485 - val_acc: 0.8481 - val_categorical_true_positives: 910.0000
# Epoch 68/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.2665 - mean_squared_error: 0.0894 - recall_25: 0.8350 - precision_25: 0.8366 - acc: 0.8356 - categorical_true_positives: 1337.0000 - val_loss: 1.2973 - val_mean_squared_error: 0.0715 - val_recall_25: 0.8602 - val_precision_25: 0.8634 - val_acc: 0.8621 - val_categorical_true_positives: 925.0000
# Epoch 69/200
# 50/50 [==============================] - 6s 113ms/step - loss: 1.1990 - mean_squared_error: 0.0891 - recall_25: 0.8163 - precision_25: 0.8183 - acc: 0.8175 - categorical_true_positives: 1308.0000 - val_loss: 1.6162 - val_mean_squared_error: 0.0808 - val_recall_25: 0.8481 - val_precision_25: 0.8513 - val_acc: 0.8500 - val_categorical_true_positives: 912.0000
# Epoch 70/200
# 50/50 [==============================] - 6s 112ms/step - loss: 1.0837 - mean_squared_error: 0.0851 - recall_25: 0.8294 - precision_25: 0.8325 - acc: 0.8313 - categorical_true_positives: 1330.0000 - val_loss: 1.2211 - val_mean_squared_error: 0.0685 - val_recall_25: 0.8658 - val_precision_25: 0.8690 - val_acc: 0.8667 - val_categorical_true_positives: 930.0000
# Epoch 71/200
# 50/50 [==============================] - 5s 110ms/step - loss: 1.2764 - mean_squared_error: 0.0934 - recall_25: 0.8163 - precision_25: 0.8178 - acc: 0.8175 - categorical_true_positives: 1308.0000 - val_loss: 1.6380 - val_mean_squared_error: 0.0813 - val_recall_25: 0.8500 - val_precision_25: 0.8523 - val_acc: 0.8518 - val_categorical_true_positives: 914.0000
# Epoch 72/200
# 50/50 [==============================] - 6s 116ms/step - loss: 1.2193 - mean_squared_error: 0.0879 - recall_25: 0.8256 - precision_25: 0.8267 - acc: 0.8263 - categorical_true_positives: 1322.0000 - val_loss: 1.2001 - val_mean_squared_error: 0.0678 - val_recall_25: 0.8602 - val_precision_25: 0.8634 - val_acc: 0.8611 - val_categorical_true_positives: 924.0000
# Epoch 73/200
# 50/50 [==============================] - 5s 108ms/step - loss: 1.0581 - mean_squared_error: 0.0828 - recall_25: 0.8375 - precision_25: 0.8385 - acc: 0.8381 - categorical_true_positives: 1341.0000 - val_loss: 1.1569 - val_mean_squared_error: 0.0652 - val_recall_25: 0.8677 - val_precision_25: 0.8717 - val_acc: 0.8714 - val_categorical_true_positives: 935.0000
# Epoch 74/200
# 50/50 [==============================] - 6s 115ms/step - loss: 1.2222 - mean_squared_error: 0.0901 - recall_25: 0.8256 - precision_25: 0.8261 - acc: 0.8263 - categorical_true_positives: 1322.0000 - val_loss: 1.1778 - val_mean_squared_error: 0.0677 - val_recall_25: 0.8630 - val_precision_25: 0.8662 - val_acc: 0.8639 - val_categorical_true_positives: 927.0000
# Epoch 75/200
# 50/50 [==============================] - 5s 107ms/step - loss: 0.9980 - mean_squared_error: 0.0787 - recall_25: 0.8450 - precision_25: 0.8461 - acc: 0.8456 - categorical_true_positives: 1353.0000 - val_loss: 1.2355 - val_mean_squared_error: 0.0708 - val_recall_25: 0.8555 - val_precision_25: 0.8587 - val_acc: 0.8583 - val_categorical_true_positives: 921.0000
# Epoch 76/200
# 50/50 [==============================] - 6s 111ms/step - loss: 1.2021 - mean_squared_error: 0.0886 - recall_25: 0.8256 - precision_25: 0.8256 - acc: 0.8256 - categorical_true_positives: 1321.0000 - val_loss: 1.1457 - val_mean_squared_error: 0.0675 - val_recall_25: 0.8630 - val_precision_25: 0.8670 - val_acc: 0.8658 - val_categorical_true_positives: 929.0000
# Epoch 77/200
# 50/50 [==============================] - 6s 111ms/step - loss: 1.2168 - mean_squared_error: 0.0890 - recall_25: 0.8231 - precision_25: 0.8242 - acc: 0.8231 - categorical_true_positives: 1317.0000 - val_loss: 1.6644 - val_mean_squared_error: 0.0810 - val_recall_25: 0.8565 - val_precision_25: 0.8589 - val_acc: 0.8565 - val_categorical_true_positives: 919.0000
# Epoch 78/200
# 50/50 [==============================] - 6s 113ms/step - loss: 1.1551 - mean_squared_error: 0.0819 - recall_25: 0.8350 - precision_25: 0.8376 - acc: 0.8369 - categorical_true_positives: 1339.0000 - val_loss: 1.2986 - val_mean_squared_error: 0.0714 - val_recall_25: 0.8667 - val_precision_25: 0.8683 - val_acc: 0.8667 - val_categorical_true_positives: 930.0000
# Epoch 79/200
# 50/50 [==============================] - 6s 116ms/step - loss: 1.1217 - mean_squared_error: 0.0841 - recall_25: 0.8356 - precision_25: 0.8377 - acc: 0.8363 - categorical_true_positives: 1338.0000 - val_loss: 1.0999 - val_mean_squared_error: 0.0633 - val_recall_25: 0.8677 - val_precision_25: 0.8693 - val_acc: 0.8695 - val_categorical_true_positives: 933.0000
# Epoch 80/200
# 50/50 [==============================] - 5s 108ms/step - loss: 1.1470 - mean_squared_error: 0.0870 - recall_25: 0.8300 - precision_25: 0.8305 - acc: 0.8306 - categorical_true_positives: 1329.0000 - val_loss: 1.1221 - val_mean_squared_error: 0.0631 - val_recall_25: 0.8788 - val_precision_25: 0.8821 - val_acc: 0.8788 - val_categorical_true_positives: 943.0000
# Epoch 81/200
# 50/50 [==============================] - 6s 115ms/step - loss: 1.0687 - mean_squared_error: 0.0811 - recall_25: 0.8413 - precision_25: 0.8413 - acc: 0.8413 - categorical_true_positives: 1346.0000 - val_loss: 1.1222 - val_mean_squared_error: 0.0659 - val_recall_25: 0.8686 - val_precision_25: 0.8718 - val_acc: 0.8686 - val_categorical_true_positives: 932.0000
# Epoch 82/200
# 50/50 [==============================] - 6s 114ms/step - loss: 1.0701 - mean_squared_error: 0.0782 - recall_25: 0.8438 - precision_25: 0.8448 - acc: 0.8438 - categorical_true_positives: 1350.0000 - val_loss: 1.2187 - val_mean_squared_error: 0.0645 - val_recall_25: 0.8788 - val_precision_25: 0.8805 - val_acc: 0.8788 - val_categorical_true_positives: 943.0000
# Epoch 83/200
# 50/50 [==============================] - 7s 130ms/step - loss: 0.9572 - mean_squared_error: 0.0740 - recall_25: 0.8512 - precision_25: 0.8523 - acc: 0.8519 - categorical_true_positives: 1363.0000 - val_loss: 1.1240 - val_mean_squared_error: 0.0609 - val_recall_25: 0.8779 - val_precision_25: 0.8812 - val_acc: 0.8807 - val_categorical_true_positives: 945.0000
# Epoch 84/200
# 50/50 [==============================] - 7s 135ms/step - loss: 0.9666 - mean_squared_error: 0.0717 - recall_25: 0.8556 - precision_25: 0.8578 - acc: 0.8562 - categorical_true_positives: 1370.0000 - val_loss: 1.1540 - val_mean_squared_error: 0.0598 - val_recall_25: 0.8844 - val_precision_25: 0.8886 - val_acc: 0.8872 - val_categorical_true_positives: 952.0000
# Epoch 85/200
# 50/50 [==============================] - 7s 134ms/step - loss: 0.9908 - mean_squared_error: 0.0714 - recall_25: 0.8562 - precision_25: 0.8568 - acc: 0.8569 - categorical_true_positives: 1371.0000 - val_loss: 1.1871 - val_mean_squared_error: 0.0600 - val_recall_25: 0.8891 - val_precision_25: 0.8899 - val_acc: 0.8891 - val_categorical_true_positives: 954.0000
# Epoch 86/200
# 50/50 [==============================] - 7s 135ms/step - loss: 1.0114 - mean_squared_error: 0.0784 - recall_25: 0.8406 - precision_25: 0.8422 - acc: 0.8419 - categorical_true_positives: 1347.0000 - val_loss: 1.5291 - val_mean_squared_error: 0.0768 - val_recall_25: 0.8649 - val_precision_25: 0.8657 - val_acc: 0.8658 - val_categorical_true_positives: 929.0000
# Epoch 87/200
# 50/50 [==============================] - 7s 137ms/step - loss: 0.9827 - mean_squared_error: 0.0703 - recall_25: 0.8656 - precision_25: 0.8656 - acc: 0.8656 - categorical_true_positives: 1385.0000 - val_loss: 1.1932 - val_mean_squared_error: 0.0639 - val_recall_25: 0.8760 - val_precision_25: 0.8801 - val_acc: 0.8788 - val_categorical_true_positives: 943.0000
# Epoch 88/200
# 50/50 [==============================] - 6s 129ms/step - loss: 1.1438 - mean_squared_error: 0.0873 - recall_25: 0.8219 - precision_25: 0.8234 - acc: 0.8225 - categorical_true_positives: 1316.0000 - val_loss: 1.0837 - val_mean_squared_error: 0.0610 - val_recall_25: 0.8760 - val_precision_25: 0.8793 - val_acc: 0.8788 - val_categorical_true_positives: 943.0000
# Epoch 89/200
# 50/50 [==============================] - 7s 137ms/step - loss: 1.0206 - mean_squared_error: 0.0746 - recall_25: 0.8550 - precision_25: 0.8561 - acc: 0.8562 - categorical_true_positives: 1370.0000 - val_loss: 1.8513 - val_mean_squared_error: 0.0877 - val_recall_25: 0.8462 - val_precision_25: 0.8470 - val_acc: 0.8472 - val_categorical_true_positives: 909.0000
# Epoch 90/200
# 50/50 [==============================] - 7s 136ms/step - loss: 1.0790 - mean_squared_error: 0.0765 - recall_25: 0.8475 - precision_25: 0.8491 - acc: 0.8481 - categorical_true_positives: 1357.0000 - val_loss: 1.0328 - val_mean_squared_error: 0.0596 - val_recall_25: 0.8788 - val_precision_25: 0.8813 - val_acc: 0.8816 - val_categorical_true_positives: 946.0000
# Epoch 91/200
# 50/50 [==============================] - 6s 126ms/step - loss: 1.0635 - mean_squared_error: 0.0788 - recall_25: 0.8406 - precision_25: 0.8412 - acc: 0.8413 - categorical_true_positives: 1346.0000 - val_loss: 1.1466 - val_mean_squared_error: 0.0611 - val_recall_25: 0.8798 - val_precision_25: 0.8822 - val_acc: 0.8816 - val_categorical_true_positives: 946.0000
# Epoch 92/200
# 50/50 [==============================] - 6s 121ms/step - loss: 0.9943 - mean_squared_error: 0.0708 - recall_25: 0.8594 - precision_25: 0.8605 - acc: 0.8600 - categorical_true_positives: 1376.0000 - val_loss: 1.1578 - val_mean_squared_error: 0.0626 - val_recall_25: 0.8779 - val_precision_25: 0.8796 - val_acc: 0.8788 - val_categorical_true_positives: 943.0000
# Epoch 93/200
# 50/50 [==============================] - 5s 107ms/step - loss: 0.9593 - mean_squared_error: 0.0720 - recall_25: 0.8525 - precision_25: 0.8530 - acc: 0.8525 - categorical_true_positives: 1364.0000 - val_loss: 1.0668 - val_mean_squared_error: 0.0601 - val_recall_25: 0.8826 - val_precision_25: 0.8842 - val_acc: 0.8844 - val_categorical_true_positives: 949.0000
# Epoch 94/200
# 50/50 [==============================] - 6s 110ms/step - loss: 0.9835 - mean_squared_error: 0.0729 - recall_25: 0.8587 - precision_25: 0.8587 - acc: 0.8587 - categorical_true_positives: 1374.0000 - val_loss: 1.1145 - val_mean_squared_error: 0.0618 - val_recall_25: 0.8760 - val_precision_25: 0.8777 - val_acc: 0.8779 - val_categorical_true_positives: 942.0000
# Epoch 95/200
# 50/50 [==============================] - 5s 107ms/step - loss: 0.9397 - mean_squared_error: 0.0676 - recall_25: 0.8637 - precision_25: 0.8643 - acc: 0.8644 - categorical_true_positives: 1383.0000 - val_loss: 1.2641 - val_mean_squared_error: 0.0666 - val_recall_25: 0.8695 - val_precision_25: 0.8728 - val_acc: 0.8714 - val_categorical_true_positives: 935.0000
# Epoch 96/200
# 50/50 [==============================] - 5s 109ms/step - loss: 0.9751 - mean_squared_error: 0.0730 - recall_25: 0.8575 - precision_25: 0.8580 - acc: 0.8581 - categorical_true_positives: 1373.0000 - val_loss: 1.0259 - val_mean_squared_error: 0.0572 - val_recall_25: 0.8826 - val_precision_25: 0.8842 - val_acc: 0.8844 - val_categorical_true_positives: 949.0000
# Epoch 97/200
# 50/50 [==============================] - 5s 109ms/step - loss: 1.0688 - mean_squared_error: 0.0709 - recall_25: 0.8606 - precision_25: 0.8612 - acc: 0.8612 - categorical_true_positives: 1378.0000 - val_loss: 1.1096 - val_mean_squared_error: 0.0597 - val_recall_25: 0.8826 - val_precision_25: 0.8834 - val_acc: 0.8826 - val_categorical_true_positives: 947.0000
# Epoch 98/200
# 50/50 [==============================] - 5s 109ms/step - loss: 0.8876 - mean_squared_error: 0.0619 - recall_25: 0.8706 - precision_25: 0.8706 - acc: 0.8706 - categorical_true_positives: 1393.0000 - val_loss: 1.3012 - val_mean_squared_error: 0.0664 - val_recall_25: 0.8733 - val_precision_25: 0.8741 - val_acc: 0.8742 - val_categorical_true_positives: 938.0000
# Epoch 99/200
# 50/50 [==============================] - 5s 106ms/step - loss: 0.9116 - mean_squared_error: 0.0662 - recall_25: 0.8700 - precision_25: 0.8711 - acc: 0.8700 - categorical_true_positives: 1392.0000 - val_loss: 1.1055 - val_mean_squared_error: 0.0572 - val_recall_25: 0.8882 - val_precision_25: 0.8890 - val_acc: 0.8891 - val_categorical_true_positives: 954.0000
# Epoch 100/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.9269 - mean_squared_error: 0.0621 - recall_25: 0.8813 - precision_25: 0.8818 - acc: 0.8819 - categorical_true_positives: 1411.0000 - val_loss: 1.0338 - val_mean_squared_error: 0.0548 - val_recall_25: 0.8928 - val_precision_25: 0.8937 - val_acc: 0.8938 - val_categorical_true_positives: 959.0000
# Epoch 101/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.9119 - mean_squared_error: 0.0627 - recall_25: 0.8794 - precision_25: 0.8805 - acc: 0.8800 - categorical_true_positives: 1408.0000 - val_loss: 1.0332 - val_mean_squared_error: 0.0574 - val_recall_25: 0.8882 - val_precision_25: 0.8898 - val_acc: 0.8891 - val_categorical_true_positives: 954.0000
# Epoch 102/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8781 - mean_squared_error: 0.0648 - recall_25: 0.8669 - precision_25: 0.8669 - acc: 0.8669 - categorical_true_positives: 1387.0000 - val_loss: 1.3417 - val_mean_squared_error: 0.0690 - val_recall_25: 0.8723 - val_precision_25: 0.8731 - val_acc: 0.8733 - val_categorical_true_positives: 937.0000
# Epoch 103/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.9257 - mean_squared_error: 0.0689 - recall_25: 0.8637 - precision_25: 0.8648 - acc: 0.8650 - categorical_true_positives: 1384.0000 - val_loss: 1.2064 - val_mean_squared_error: 0.0637 - val_recall_25: 0.8760 - val_precision_25: 0.8785 - val_acc: 0.8779 - val_categorical_true_positives: 942.0000
# Epoch 104/200
# 50/50 [==============================] - 4s 87ms/step - loss: 1.0095 - mean_squared_error: 0.0687 - recall_25: 0.8650 - precision_25: 0.8655 - acc: 0.8650 - categorical_true_positives: 1384.0000 - val_loss: 1.1539 - val_mean_squared_error: 0.0620 - val_recall_25: 0.8835 - val_precision_25: 0.8843 - val_acc: 0.8844 - val_categorical_true_positives: 949.0000
# Epoch 105/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8687 - mean_squared_error: 0.0627 - recall_25: 0.8775 - precision_25: 0.8791 - acc: 0.8781 - categorical_true_positives: 1405.0000 - val_loss: 1.3596 - val_mean_squared_error: 0.0699 - val_recall_25: 0.8742 - val_precision_25: 0.8750 - val_acc: 0.8751 - val_categorical_true_positives: 939.0000
# Epoch 106/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8749 - mean_squared_error: 0.0635 - recall_25: 0.8769 - precision_25: 0.8769 - acc: 0.8769 - categorical_true_positives: 1403.0000 - val_loss: 1.0459 - val_mean_squared_error: 0.0561 - val_recall_25: 0.8938 - val_precision_25: 0.8963 - val_acc: 0.8947 - val_categorical_true_positives: 960.0000
# Epoch 107/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8873 - mean_squared_error: 0.0607 - recall_25: 0.8869 - precision_25: 0.8869 - acc: 0.8869 - categorical_true_positives: 1419.0000 - val_loss: 0.9825 - val_mean_squared_error: 0.0515 - val_recall_25: 0.9003 - val_precision_25: 0.9011 - val_acc: 0.9012 - val_categorical_true_positives: 967.0000
# Epoch 108/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.9225 - mean_squared_error: 0.0625 - recall_25: 0.8825 - precision_25: 0.8831 - acc: 0.8825 - categorical_true_positives: 1412.0000 - val_loss: 1.0763 - val_mean_squared_error: 0.0546 - val_recall_25: 0.8938 - val_precision_25: 0.8946 - val_acc: 0.8947 - val_categorical_true_positives: 960.0000
# Epoch 109/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8525 - mean_squared_error: 0.0546 - recall_25: 0.8950 - precision_25: 0.8956 - acc: 0.8950 - categorical_true_positives: 1432.0000 - val_loss: 1.1385 - val_mean_squared_error: 0.0569 - val_recall_25: 0.8919 - val_precision_25: 0.8927 - val_acc: 0.8928 - val_categorical_true_positives: 958.0000
# Epoch 110/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8581 - mean_squared_error: 0.0592 - recall_25: 0.8856 - precision_25: 0.8856 - acc: 0.8856 - categorical_true_positives: 1417.0000 - val_loss: 1.0463 - val_mean_squared_error: 0.0549 - val_recall_25: 0.8910 - val_precision_25: 0.8918 - val_acc: 0.8910 - val_categorical_true_positives: 956.0000
# Epoch 111/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8636 - mean_squared_error: 0.0595 - recall_25: 0.8856 - precision_25: 0.8856 - acc: 0.8856 - categorical_true_positives: 1417.0000 - val_loss: 1.1135 - val_mean_squared_error: 0.0586 - val_recall_25: 0.8882 - val_precision_25: 0.8890 - val_acc: 0.8882 - val_categorical_true_positives: 953.0000
# Epoch 112/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8089 - mean_squared_error: 0.0527 - recall_25: 0.8981 - precision_25: 0.8987 - acc: 0.8988 - categorical_true_positives: 1438.0000 - val_loss: 1.0154 - val_mean_squared_error: 0.0526 - val_recall_25: 0.8956 - val_precision_25: 0.8956 - val_acc: 0.8956 - val_categorical_true_positives: 961.0000
# Epoch 113/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8469 - mean_squared_error: 0.0560 - recall_25: 0.8944 - precision_25: 0.8955 - acc: 0.8950 - categorical_true_positives: 1432.0000 - val_loss: 1.0090 - val_mean_squared_error: 0.0496 - val_recall_25: 0.9031 - val_precision_25: 0.9039 - val_acc: 0.9031 - val_categorical_true_positives: 969.0000
# Epoch 114/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8499 - mean_squared_error: 0.0575 - recall_25: 0.8831 - precision_25: 0.8837 - acc: 0.8831 - categorical_true_positives: 1413.0000 - val_loss: 0.9306 - val_mean_squared_error: 0.0454 - val_recall_25: 0.9105 - val_precision_25: 0.9114 - val_acc: 0.9115 - val_categorical_true_positives: 978.0000
# Epoch 115/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8396 - mean_squared_error: 0.0570 - recall_25: 0.8794 - precision_25: 0.8799 - acc: 0.8794 - categorical_true_positives: 1407.0000 - val_loss: 1.1138 - val_mean_squared_error: 0.0559 - val_recall_25: 0.8956 - val_precision_25: 0.8965 - val_acc: 0.8966 - val_categorical_true_positives: 962.0000
# Epoch 116/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8452 - mean_squared_error: 0.0617 - recall_25: 0.8756 - precision_25: 0.8762 - acc: 0.8763 - categorical_true_positives: 1402.0000 - val_loss: 0.8517 - val_mean_squared_error: 0.0415 - val_recall_25: 0.9180 - val_precision_25: 0.9197 - val_acc: 0.9189 - val_categorical_true_positives: 986.0000
# Epoch 117/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8637 - mean_squared_error: 0.0588 - recall_25: 0.8825 - precision_25: 0.8825 - acc: 0.8825 - categorical_true_positives: 1412.0000 - val_loss: 0.9513 - val_mean_squared_error: 0.0474 - val_recall_25: 0.9096 - val_precision_25: 0.9096 - val_acc: 0.9096 - val_categorical_true_positives: 976.0000
# Epoch 118/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8317 - mean_squared_error: 0.0550 - recall_25: 0.8938 - precision_25: 0.8938 - acc: 0.8938 - categorical_true_positives: 1430.0000 - val_loss: 0.8721 - val_mean_squared_error: 0.0437 - val_recall_25: 0.9152 - val_precision_25: 0.9169 - val_acc: 0.9171 - val_categorical_true_positives: 984.0000
# Epoch 119/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.7987 - mean_squared_error: 0.0511 - recall_25: 0.8931 - precision_25: 0.8948 - acc: 0.8938 - categorical_true_positives: 1430.0000 - val_loss: 1.0651 - val_mean_squared_error: 0.0536 - val_recall_25: 0.8975 - val_precision_25: 0.8983 - val_acc: 0.8975 - val_categorical_true_positives: 963.0000
# Epoch 120/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8456 - mean_squared_error: 0.0571 - recall_25: 0.8869 - precision_25: 0.8874 - acc: 0.8875 - categorical_true_positives: 1420.0000 - val_loss: 0.8793 - val_mean_squared_error: 0.0455 - val_recall_25: 0.9152 - val_precision_25: 0.9160 - val_acc: 0.9152 - val_categorical_true_positives: 982.0000
# Epoch 121/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.8215 - mean_squared_error: 0.0485 - recall_25: 0.9106 - precision_25: 0.9106 - acc: 0.9106 - categorical_true_positives: 1457.0000 - val_loss: 1.0246 - val_mean_squared_error: 0.0515 - val_recall_25: 0.9012 - val_precision_25: 0.9012 - val_acc: 0.9012 - val_categorical_true_positives: 967.0000
# Epoch 122/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8962 - mean_squared_error: 0.0564 - recall_25: 0.8900 - precision_25: 0.8906 - acc: 0.8900 - categorical_true_positives: 1424.0000 - val_loss: 1.1007 - val_mean_squared_error: 0.0556 - val_recall_25: 0.9012 - val_precision_25: 0.9012 - val_acc: 0.9012 - val_categorical_true_positives: 967.0000
# Epoch 123/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.8024 - mean_squared_error: 0.0487 - recall_25: 0.9038 - precision_25: 0.9038 - acc: 0.9038 - categorical_true_positives: 1446.0000 - val_loss: 1.1529 - val_mean_squared_error: 0.0573 - val_recall_25: 0.9012 - val_precision_25: 0.9012 - val_acc: 0.9012 - val_categorical_true_positives: 967.0000
# Epoch 124/200
# ...
# Epoch 159/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6746 - mean_squared_error: 0.0328 - recall_25: 0.9331 - precision_25: 0.9331 - acc: 0.9331 - categorical_true_positives: 1493.0000 - val_loss: 0.8089 - val_mean_squared_error: 0.0331 - val_recall_25: 0.9376 - val_precision_25: 0.9376 - val_acc: 0.9376 - val_categorical_true_positives: 1006.0000
# Epoch 160/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6509 - mean_squared_error: 0.0282 - recall_25: 0.9475 - precision_25: 0.9475 - acc: 0.9475 - categorical_true_positives: 1516.0000 - val_loss: 0.7118 - val_mean_squared_error: 0.0282 - val_recall_25: 0.9422 - val_precision_25: 0.9422 - val_acc: 0.9422 - val_categorical_true_positives: 1011.0000
# Epoch 161/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6378 - mean_squared_error: 0.0261 - recall_25: 0.9463 - precision_25: 0.9468 - acc: 0.9463 - categorical_true_positives: 1514.0000 - val_loss: 0.7922 - val_mean_squared_error: 0.0320 - val_recall_25: 0.9385 - val_precision_25: 0.9385 - val_acc: 0.9385 - val_categorical_true_positives: 1007.0000
# Epoch 162/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6642 - mean_squared_error: 0.0270 - recall_25: 0.9475 - precision_25: 0.9475 - acc: 0.9475 - categorical_true_positives: 1516.0000 - val_loss: 0.8373 - val_mean_squared_error: 0.0340 - val_recall_25: 0.9348 - val_precision_25: 0.9356 - val_acc: 0.9357 - val_categorical_true_positives: 1004.0000
# Epoch 163/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6367 - mean_squared_error: 0.0272 - recall_25: 0.9406 - precision_25: 0.9406 - acc: 0.9406 - categorical_true_positives: 1505.0000 - val_loss: 0.8182 - val_mean_squared_error: 0.0329 - val_recall_25: 0.9385 - val_precision_25: 0.9385 - val_acc: 0.9385 - val_categorical_true_positives: 1007.0000
# Epoch 164/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6484 - mean_squared_error: 0.0238 - recall_25: 0.9556 - precision_25: 0.9556 - acc: 0.9556 - categorical_true_positives: 1529.0000 - val_loss: 0.7612 - val_mean_squared_error: 0.0305 - val_recall_25: 0.9385 - val_precision_25: 0.9394 - val_acc: 0.9385 - val_categorical_true_positives: 1007.0000
# Epoch 165/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6376 - mean_squared_error: 0.0268 - recall_25: 0.9456 - precision_25: 0.9456 - acc: 0.9456 - categorical_true_positives: 1513.0000 - val_loss: 0.8666 - val_mean_squared_error: 0.0348 - val_recall_25: 0.9366 - val_precision_25: 0.9366 - val_acc: 0.9366 - val_categorical_true_positives: 1005.0000
# Epoch 166/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6786 - mean_squared_error: 0.0294 - recall_25: 0.9463 - precision_25: 0.9463 - acc: 0.9463 - categorical_true_positives: 1514.0000 - val_loss: 0.6696 - val_mean_squared_error: 0.0242 - val_recall_25: 0.9487 - val_precision_25: 0.9487 - val_acc: 0.9487 - val_categorical_true_positives: 1018.0000
# Epoch 167/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6185 - mean_squared_error: 0.0253 - recall_25: 0.9400 - precision_25: 0.9406 - acc: 0.9400 - categorical_true_positives: 1504.0000 - val_loss: 0.6794 - val_mean_squared_error: 0.0254 - val_recall_25: 0.9487 - val_precision_25: 0.9487 - val_acc: 0.9487 - val_categorical_true_positives: 1018.0000
# Epoch 168/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6100 - mean_squared_error: 0.0217 - recall_25: 0.9544 - precision_25: 0.9544 - acc: 0.9544 - categorical_true_positives: 1527.0000 - val_loss: 0.6986 - val_mean_squared_error: 0.0265 - val_recall_25: 0.9469 - val_precision_25: 0.9469 - val_acc: 0.9469 - val_categorical_true_positives: 1016.0000
# Epoch 169/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6118 - mean_squared_error: 0.0238 - recall_25: 0.9506 - precision_25: 0.9506 - acc: 0.9506 - categorical_true_positives: 1521.0000 - val_loss: 0.7556 - val_mean_squared_error: 0.0317 - val_recall_25: 0.9394 - val_precision_25: 0.9394 - val_acc: 0.9394 - val_categorical_true_positives: 1008.0000
# Epoch 170/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6243 - mean_squared_error: 0.0229 - recall_25: 0.9544 - precision_25: 0.9544 - acc: 0.9544 - categorical_true_positives: 1527.0000 - val_loss: 0.6705 - val_mean_squared_error: 0.0216 - val_recall_25: 0.9562 - val_precision_25: 0.9562 - val_acc: 0.9562 - val_categorical_true_positives: 1026.0000
# Epoch 171/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6334 - mean_squared_error: 0.0207 - recall_25: 0.9544 - precision_25: 0.9544 - acc: 0.9544 - categorical_true_positives: 1527.0000 - val_loss: 0.7664 - val_mean_squared_error: 0.0315 - val_recall_25: 0.9404 - val_precision_25: 0.9404 - val_acc: 0.9404 - val_categorical_true_positives: 1009.0000
# Epoch 172/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6264 - mean_squared_error: 0.0226 - recall_25: 0.9513 - precision_25: 0.9513 - acc: 0.9513 - categorical_true_positives: 1522.0000 - val_loss: 0.7383 - val_mean_squared_error: 0.0292 - val_recall_25: 0.9413 - val_precision_25: 0.9413 - val_acc: 0.9413 - val_categorical_true_positives: 1010.0000
# Epoch 173/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6113 - mean_squared_error: 0.0199 - recall_25: 0.9606 - precision_25: 0.9606 - acc: 0.9606 - categorical_true_positives: 1537.0000 - val_loss: 0.7203 - val_mean_squared_error: 0.0274 - val_recall_25: 0.9478 - val_precision_25: 0.9478 - val_acc: 0.9478 - val_categorical_true_positives: 1017.0000
# Epoch 174/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6571 - mean_squared_error: 0.0246 - recall_25: 0.9481 - precision_25: 0.9481 - acc: 0.9481 - categorical_true_positives: 1517.0000 - val_loss: 0.7706 - val_mean_squared_error: 0.0308 - val_recall_25: 0.9404 - val_precision_25: 0.9404 - val_acc: 0.9404 - val_categorical_true_positives: 1009.0000
# Epoch 175/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.6227 - mean_squared_error: 0.0255 - recall_25: 0.9456 - precision_25: 0.9456 - acc: 0.9456 - categorical_true_positives: 1513.0000 - val_loss: 0.6938 - val_mean_squared_error: 0.0256 - val_recall_25: 0.9487 - val_precision_25: 0.9487 - val_acc: 0.9487 - val_categorical_true_positives: 1018.0000
# Epoch 176/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6082 - mean_squared_error: 0.0191 - recall_25: 0.9613 - precision_25: 0.9613 - acc: 0.9613 - categorical_true_positives: 1538.0000 - val_loss: 0.6589 - val_mean_squared_error: 0.0243 - val_recall_25: 0.9515 - val_precision_25: 0.9515 - val_acc: 0.9515 - val_categorical_true_positives: 1021.0000
# Epoch 177/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6258 - mean_squared_error: 0.0176 - recall_25: 0.9631 - precision_25: 0.9637 - acc: 0.9638 - categorical_true_positives: 1542.0000 - val_loss: 0.6285 - val_mean_squared_error: 0.0214 - val_recall_25: 0.9581 - val_precision_25: 0.9581 - val_acc: 0.9581 - val_categorical_true_positives: 1028.0000
# Epoch 178/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6080 - mean_squared_error: 0.0166 - recall_25: 0.9725 - precision_25: 0.9725 - acc: 0.9725 - categorical_true_positives: 1556.0000 - val_loss: 0.7463 - val_mean_squared_error: 0.0294 - val_recall_25: 0.9441 - val_precision_25: 0.9441 - val_acc: 0.9441 - val_categorical_true_positives: 1013.0000
# Epoch 179/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6159 - mean_squared_error: 0.0205 - recall_25: 0.9594 - precision_25: 0.9594 - acc: 0.9594 - categorical_true_positives: 1535.0000 - val_loss: 0.7515 - val_mean_squared_error: 0.0294 - val_recall_25: 0.9459 - val_precision_25: 0.9459 - val_acc: 0.9459 - val_categorical_true_positives: 1015.0000
# Epoch 180/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6026 - mean_squared_error: 0.0196 - recall_25: 0.9638 - precision_25: 0.9644 - acc: 0.9644 - categorical_true_positives: 1543.0000 - val_loss: 0.7167 - val_mean_squared_error: 0.0280 - val_recall_25: 0.9459 - val_precision_25: 0.9459 - val_acc: 0.9459 - val_categorical_true_positives: 1015.0000
# Epoch 181/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5799 - mean_squared_error: 0.0155 - recall_25: 0.9694 - precision_25: 0.9694 - acc: 0.9694 - categorical_true_positives: 1551.0000 - val_loss: 0.7251 - val_mean_squared_error: 0.0281 - val_recall_25: 0.9441 - val_precision_25: 0.9441 - val_acc: 0.9441 - val_categorical_true_positives: 1013.0000
# Epoch 182/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5762 - mean_squared_error: 0.0158 - recall_25: 0.9681 - precision_25: 0.9681 - acc: 0.9681 - categorical_true_positives: 1549.0000 - val_loss: 0.6921 - val_mean_squared_error: 0.0261 - val_recall_25: 0.9506 - val_precision_25: 0.9506 - val_acc: 0.9506 - val_categorical_true_positives: 1020.0000
# Epoch 183/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6050 - mean_squared_error: 0.0181 - recall_25: 0.9650 - precision_25: 0.9650 - acc: 0.9650 - categorical_true_positives: 1544.0000 - val_loss: 0.6116 - val_mean_squared_error: 0.0190 - val_recall_25: 0.9609 - val_precision_25: 0.9609 - val_acc: 0.9609 - val_categorical_true_positives: 1031.0000
# Epoch 184/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6078 - mean_squared_error: 0.0180 - recall_25: 0.9669 - precision_25: 0.9669 - acc: 0.9669 - categorical_true_positives: 1547.0000 - val_loss: 0.6100 - val_mean_squared_error: 0.0190 - val_recall_25: 0.9562 - val_precision_25: 0.9562 - val_acc: 0.9562 - val_categorical_true_positives: 1026.0000
# Epoch 185/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6328 - mean_squared_error: 0.0177 - recall_25: 0.9694 - precision_25: 0.9694 - acc: 0.9694 - categorical_true_positives: 1551.0000 - val_loss: 0.7643 - val_mean_squared_error: 0.0285 - val_recall_25: 0.9432 - val_precision_25: 0.9432 - val_acc: 0.9432 - val_categorical_true_positives: 1012.0000
# Epoch 186/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5851 - mean_squared_error: 0.0161 - recall_25: 0.9681 - precision_25: 0.9687 - acc: 0.9681 - categorical_true_positives: 1549.0000 - val_loss: 0.5824 - val_mean_squared_error: 0.0175 - val_recall_25: 0.9655 - val_precision_25: 0.9655 - val_acc: 0.9655 - val_categorical_true_positives: 1036.0000
# Epoch 187/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6044 - mean_squared_error: 0.0190 - recall_25: 0.9644 - precision_25: 0.9644 - acc: 0.9644 - categorical_true_positives: 1543.0000 - val_loss: 0.7856 - val_mean_squared_error: 0.0307 - val_recall_25: 0.9432 - val_precision_25: 0.9432 - val_acc: 0.9432 - val_categorical_true_positives: 1012.0000
# Epoch 188/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5615 - mean_squared_error: 0.0140 - recall_25: 0.9737 - precision_25: 0.9737 - acc: 0.9737 - categorical_true_positives: 1558.0000 - val_loss: 0.5732 - val_mean_squared_error: 0.0182 - val_recall_25: 0.9581 - val_precision_25: 0.9581 - val_acc: 0.9581 - val_categorical_true_positives: 1028.0000
# Epoch 189/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5797 - mean_squared_error: 0.0147 - recall_25: 0.9750 - precision_25: 0.9750 - acc: 0.9750 - categorical_true_positives: 1560.0000 - val_loss: 0.6122 - val_mean_squared_error: 0.0198 - val_recall_25: 0.9571 - val_precision_25: 0.9571 - val_acc: 0.9571 - val_categorical_true_positives: 1027.0000
# Epoch 190/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5618 - mean_squared_error: 0.0123 - recall_25: 0.9800 - precision_25: 0.9800 - acc: 0.9800 - categorical_true_positives: 1568.0000 - val_loss: 0.6913 - val_mean_squared_error: 0.0247 - val_recall_25: 0.9497 - val_precision_25: 0.9497 - val_acc: 0.9497 - val_categorical_true_positives: 1019.0000
# Epoch 191/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5773 - mean_squared_error: 0.0156 - recall_25: 0.9700 - precision_25: 0.9700 - acc: 0.9700 - categorical_true_positives: 1552.0000 - val_loss: 0.7639 - val_mean_squared_error: 0.0282 - val_recall_25: 0.9450 - val_precision_25: 0.9450 - val_acc: 0.9450 - val_categorical_true_positives: 1014.0000
# Epoch 192/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5651 - mean_squared_error: 0.0135 - recall_25: 0.9719 - precision_25: 0.9719 - acc: 0.9719 - categorical_true_positives: 1555.0000 - val_loss: 0.6025 - val_mean_squared_error: 0.0208 - val_recall_25: 0.9562 - val_precision_25: 0.9562 - val_acc: 0.9562 - val_categorical_true_positives: 1026.0000
# Epoch 193/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6008 - mean_squared_error: 0.0162 - recall_25: 0.9712 - precision_25: 0.9712 - acc: 0.9712 - categorical_true_positives: 1554.0000 - val_loss: 0.7084 - val_mean_squared_error: 0.0251 - val_recall_25: 0.9506 - val_precision_25: 0.9506 - val_acc: 0.9506 - val_categorical_true_positives: 1020.0000
# Epoch 194/200
# 50/50 [==============================] - 4s 86ms/step - loss: 0.5483 - mean_squared_error: 0.0112 - recall_25: 0.9762 - precision_25: 0.9769 - acc: 0.9762 - categorical_true_positives: 1562.0000 - val_loss: 0.6718 - val_mean_squared_error: 0.0238 - val_recall_25: 0.9534 - val_precision_25: 0.9534 - val_acc: 0.9534 - val_categorical_true_positives: 1023.0000
# Epoch 195/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5779 - mean_squared_error: 0.0149 - recall_25: 0.9744 - precision_25: 0.9744 - acc: 0.9744 - categorical_true_positives: 1559.0000 - val_loss: 0.6182 - val_mean_squared_error: 0.0203 - val_recall_25: 0.9599 - val_precision_25: 0.9599 - val_acc: 0.9599 - val_categorical_true_positives: 1030.0000
# Epoch 196/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5651 - mean_squared_error: 0.0130 - recall_25: 0.9744 - precision_25: 0.9744 - acc: 0.9744 - categorical_true_positives: 1559.0000 - val_loss: 0.6616 - val_mean_squared_error: 0.0214 - val_recall_25: 0.9571 - val_precision_25: 0.9571 - val_acc: 0.9571 - val_categorical_true_positives: 1027.0000
# Epoch 197/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5770 - mean_squared_error: 0.0153 - recall_25: 0.9694 - precision_25: 0.9694 - acc: 0.9694 - categorical_true_positives: 1551.0000 - val_loss: 1.0200 - val_mean_squared_error: 0.0368 - val_recall_25: 0.9329 - val_precision_25: 0.9329 - val_acc: 0.9329 - val_categorical_true_positives: 1001.0000
# Epoch 198/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5638 - mean_squared_error: 0.0113 - recall_25: 0.9800 - precision_25: 0.9800 - acc: 0.9800 - categorical_true_positives: 1568.0000 - val_loss: 0.8211 - val_mean_squared_error: 0.0283 - val_recall_25: 0.9478 - val_precision_25: 0.9478 - val_acc: 0.9478 - val_categorical_true_positives: 1017.0000
# Epoch 199/200
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5707 - mean_squared_error: 0.0123 - recall_25: 0.9787 - precision_25: 0.9787 - acc: 0.9787 - categorical_true_positives: 1566.0000 - val_loss: 0.5671 - val_mean_squared_error: 0.0168 - val_recall_25: 0.9646 - val_precision_25: 0.9646 - val_acc: 0.9646 - val_categorical_true_positives: 1035.0000
# Epoch 200/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5506 - mean_squared_error: 0.0119 - recall_25: 0.9794 - precision_25: 0.9794 - acc: 0.9794 - categorical_true_positives: 1567.0000 - val_loss: 0.5615 - val_mean_squared_error: 0.0158 - val_recall_25: 0.9664 - val_precision_25: 0.9664 - val_acc: 0.9664 - val_categorical_true_positives: 1037.0000

# %%
result = build_triplet.predict(X_val)
preds_raw = np.argmax(result, axis=1)
preds = K.one_hot(preds_raw, nb_classes+1)

print("\nTrue positives per classes:")
for i in range(nb_classes+1):
    m = tf.keras.metrics.TruePositives(name='tp')    
    m.update_state(labels_val[:, i], preds[:, i])
    print("Class {} true positives: {}".format(i, m.result()))
    
r = tf.keras.metrics.Recall()
r.update_state(labels_val, preds)
r.result().numpy()
print('Recall ' + str(r.result()))

p = tf.keras.metrics.Precision()
p.update_state(labels_val, preds)
p.result().numpy()
print('Precision ' + str(p.result()))

f1 = 2*((p.result()*r.result())/(p.result()+r.result()+K.epsilon()))
print('F1 ' + str(f1))

import statistics
acc = statistics.mean(history.history['val_acc']) 
print('accuracy ' + str(acc))
# Out:
# True positives per classes:
# Class 0 true positives: 0.0
# Class 1 true positives: 0.0
# Class 2 true positives: 0.0
# Recall tf.Tensor(0.0, shape=(), dtype=float32)
# Precision tf.Tensor(0.0, shape=(), dtype=float32)
# F1 tf.Tensor(0.0, shape=(), dtype=float32)
# accuracy 0.9195200371742248

# %%
labels_test = K.one_hot(Y_test, nb_classes+1)
result = build_triplet.predict(X_test)
preds_raw = np.argmax(result, axis=1)
preds = K.one_hot(preds_raw, nb_classes+1)
    
r = tf.keras.metrics.Recall()
r.update_state(labels_test, preds)
r.result().numpy()
print('Recall ' + str(r.result()))

p = tf.keras.metrics.Precision()
p.update_state(labels_test, preds)
p.result().numpy()
print('Precision ' + str(p.result()))

f1 = 2*((p.result()*r.result())/(p.result()+r.result()+K.epsilon()))
print('F1 ' + str(f1))

import statistics
acc = statistics.mean(history.history['val_acc']) 
print('accuracy ' + str(acc))
# Out:
# Recall tf.Tensor(0.9992453, shape=(), dtype=float32)
# Precision tf.Tensor(0.9992453, shape=(), dtype=float32)
# F1 tf.Tensor(0.9992452, shape=(), dtype=float32)
# accuracy 0.9195200371742248

# %% [markdown]
# ### Plotting

# %%
import pickle

with open(os.path.abspath(os.path.join('../../results/14/')), 'wb') as file_pi:
     pickle.dump(history.history, file_pi)

# %%
print('hi')
# Out:
# hi

# %%
history_retrieve = pickle.load(open(os.path.abspath(os.path.join('../../results/14/')), "rb"))

# %%
# summarize history for accuracy
plt.plot(history_retrieve['acc'])
plt.plot(history_retrieve['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history_retrieve['loss'])
plt.plot(history_retrieve['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
