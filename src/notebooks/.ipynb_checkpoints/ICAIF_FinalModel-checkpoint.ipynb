# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import sys
import tensorflow as tf
import time
from pylab import *
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer
from skimage.util.shape import view_as_windows
from sklearn.metrics import roc_curve,roc_auc_score
from tcn import TCN, tcn_full_summary
from tensorflow.keras.layers import Dense, Conv2D, Layer, Lambda, Flatten
from tensorflow.keras import Input, Model, metrics
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.python.client import device_lib

module_path = os.path.abspath(os.path.join('..'))
project_path = os.path.abspath(os.path.join('../..'))
train_source = os.path.abspath(os.path.join('../../data/train_source/'))
test_source = os.path.abspath(os.path.join('../../data/test_source/'))
train_path = os.path.abspath(os.path.join('../../data/train/'))
test_path = os.path.abspath(os.path.join('../../data/test/'))
dest_path_bsu = os.path.abspath(os.path.join('../../data/final_bsu/'))
dest_path_bs = os.path.abspath(os.path.join('../../data/final_bs/'))
val_path_bs = os.path.abspath(os.path.join('../../data/validation_bs/'))
val_path_bsu = os.path.abspath(os.path.join('../../data/validation_bsu/'))

if module_path not in sys.path:
    sys.path.append(module_path)
if project_path not in sys.path:
    sys.path.append(project_path)
    
np.set_printoptions(suppress=True)
np.set_printoptions(threshold=sys.maxsize)
#print(device_lib.list_local_devices())

# %%
# 1. Train 10 without weights 128 bs - DONE
# 2. Train 10 without weights 256 bs - DONE
# 3. Train 10 without weights 1024 bs - DONE
# 4. Train 10 weights 128 bs - DONE
# 5. Train 10 weights 256 bs - DONE
# 6. Train 10 weights 1024 bs - DONE
# 7. Train 10 without weights 128 bsu
# 8. Train 10 without weights 256 bsu
# 9. Train 10 without weights 1024 bsu
# 10. Train 10 weights 128 bsu
# 11. Train 10 weights 256 bsu
# 12. Train 10 weights 1024 bsu

---------------------------------------------

# 13. Train 50 without weights 128 bs - RUNNING
# 14. Train 50 without weights 256 bs
# 15. Train 50 without weights 1024 bs
# 16. Train 50 weights 128 bs
# 17. Train 50 weights 256 bs
# 18. Train 50 weights 1024 bs
# 19. Train 50 without weights 128 bsu
# 20. Train 50 without weights 256 bsu
# 21. Train 50 without weights 1024 bsu
# 22. Train 50 weights 128 bsu
# 23. Train 50 weights 256 bsu
# 24. Train 50 weights 1024 bsu

# %%
# Hyperparameters
nb_classes=2
cols, rows = 2, 30
input_shape = (cols, rows, 1)
vol_imb_diff = 0.1
evaluate_every = 100 # interval for evaluating on one-shot tasks
batch_size = 32
n_iter = 20000 # No. of training iterations
n_val = 250 # how many one-shot tasks to validate on
h = 30
w = 2
d = 2

# %%
num_frames = 50
# FOR BS Training 
# Train
X_train = np.load(dest_path_bs + '/' + str(num_frames) + '_X_train.npy')
Y_train = np.load(dest_path_bs + '/' + str(num_frames) + '_Y_train.npy')
F_train = np.load(dest_path_bs + '/' + str(num_frames) + '_F_train.npy')
X_test = np.load(dest_path_bs + '/' + str(num_frames) + '_X_test.npy')
Y_test = np.load(dest_path_bs + '/' + str(num_frames) + '_Y_test.npy')
F_test = np.load(dest_path_bs + '/' + str(num_frames) + '_F_test.npy')

print(X_train.shape)
print(X_test.shape)

#X_train = np.append(X_train, X_test, axis=0)
#Y_train = np.append(Y_train, Y_test, axis=0)
#F_train = np.append(F_train, F_test, axis=0)
#print(X_train.shape)

# Validation
X_val = np.load(val_path_bs + '/' + str(num_frames) + '_X_val.npy')
Y_val = np.load(val_path_bs + '/' + str(num_frames) + '_Y_val.npy')
print(X_val.shape)
# Out:
# (53649, 50, 30, 2, 2)
# (19875, 50, 30, 2, 2)
# (178000, 50, 30, 2, 2)

# %%
# FOR BSU Training 
# Train
Xu_train = np.load(dest_path_bsu + '/' + str(num_frames) + '_X_train.npy')
Yu_train = np.load(dest_path_bsu + '/' + str(num_frames) + '_Y_train.npy')
Fu_train = np.load(dest_path_bsu + '/' + str(num_frames) + '_F_train.npy')
Xu_test = np.load(dest_path_bsu + '/' + str(num_frames) + '_X_test.npy')
Yu_test = np.load(dest_path_bsu + '/' + str(num_frames) + '_Y_test.npy')
Fu_test = np.load(dest_path_bsu + '/' + str(num_frames) + '_F_test.npy')

print(Xu_train.shape)
print(Xu_test.shape)

Xu_train = np.append(Xu_train, Xu_test, axis=0)
Yu_train = np.append(Yu_train, Yu_test, axis=0)
Fu_train = np.append(Fu_train, Fu_test, axis=0)
print(Xu_train.shape)

# Validation
Xu_val = np.load(val_path_bsu + '/' + str(num_frames) + '_X_val.npy')
Yu_val = np.load(val_path_bsu + '/' + str(num_frames) + '_Y_val.npy')

# %%
# COMBINE BS AND BSU
X_train = np.append(X_train, Xu_train, axis=0)
Y_train = np.append(Y_train, Yu_train, axis=0)
F_train = np.append(F_train, Fu_train, axis=0)
print(X_train.shape)

X_val = np.append(X_val, Xu_val, axis=0)
Y_val = np.append(Y_val, Yu_val, axis=0)
print(X_val.shape)

# %% [markdown]
# ### Model Initialisation

# %%
def initialize_weights(shape, name=None, dtype=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer weights with mean as 0.0 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

def initialize_bias(shape, name=None, dtype=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer bias with mean as 0.5 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# Intialize bias with mean 0.0 and standard deviation of 10^-2
weights = initialize_weights((1000,1))
sns.distplot(weights)
plt.title("Plot of weights initialized, with mean of 0.0 and standard deviation of 0.01")

# Intialize bias with mean 0.5 and standard deviation of 10^-2
bias = initialize_bias((1000,1))
sns.distplot(bias)
plt.title("Plot of biases initialized, with mean of 0.0 and standard deviation of 0.01")
# Out:
# Text(0.5, 1.0, 'Plot of biases initialized, with mean of 0.0 and standard deviation of 0.01')

# %%
class CategoricalTruePositives(tf.keras.metrics.Metric):
    def __init__(self, num_classes, batch_size,
                 name="categorical_true_positives", **kwargs):
        super(CategoricalTruePositives, self).__init__(name=name, **kwargs)

        self.batch_size = batch_size
        self.num_classes = num_classes    

        self.cat_true_positives = self.add_weight(name="ctp", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):     

        y_true = K.argmax(y_true, axis=-1)
        y_pred = K.argmax(y_pred, axis=-1)
        y_true = K.flatten(y_true)

        true_poss = K.sum(K.cast((K.equal(y_true, y_pred)), dtype=tf.float32))
        self.cat_true_positives.assign_add(true_poss)

    def result(self):
        return self.cat_true_positives

# %%
def embedding_model(frames, h, w, c, input_shape, dimensions, include_top=False, pooling=None, classes=1):  
    inp = Input(shape=(frames, h, w, c))
    out = Lambda(lambda y: K.reshape(y, (-1, h, w, c)))(inp)
    num_features_cnn = np.prod(K.int_shape(out)[1:])
    out = Lambda(lambda y: K.reshape(y, (-1, num_frames, num_features_cnn)))(inp)
    out = TCN(nb_filters=128, kernel_size=2, return_sequences=False, dilations=[1, 2, 4, 8, 16, 32, 64], 
              activation=tf.keras.activations.swish, nb_stacks=1, dropout_rate=0.08)(out)
    out = Flatten()(out)
    out = Dense(128, activation=None, kernel_regularizer=l2(1e-3), kernel_initializer='he_uniform')(out)    
    return Model(inputs=inp, outputs=out)

def triplets_model(input_shape, embedding, include_top=False, pooling=None):
    anchor_input = Input(shape=input_shape, name='anchor_input')
    encoded_a = embedding(anchor_input)
    prediction = Dense(nb_classes+1, activation='softmax',bias_initializer=initialize_bias)(encoded_a)
    triplet_net = Model(inputs=[anchor_input],outputs=[prediction])
    return triplet_net

build_embedding = embedding_model(num_frames, h, w, d, input_shape=(num_frames, h, w, d), dimensions=60)
build_triplet = triplets_model(input_shape=(num_frames, h, w, d), embedding=build_embedding)
optimizer = Adam(lr = 0.00006)
build_triplet.compile(loss=tf.keras.losses.CategoricalCrossentropy(),optimizer=optimizer, 
                      metrics=[metrics.MeanSquaredError(), tf.keras.metrics.Recall(), tf.keras.metrics.Precision(),
                      tf.keras.metrics.CategoricalAccuracy(name='acc'),
                      CategoricalTruePositives(nb_classes, batch_size)])
build_embedding.summary()
build_triplet.summary()
tcn_full_summary(build_embedding, expand_residual_blocks=True)
plot_model(build_embedding, 'multi_input_and_output_model.png', show_shapes=True)
# Out:
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 50, 30, 2, 2)]    0
# _________________________________________________________________
# lambda_19 (Lambda)           (None, 50, 120)           0
# _________________________________________________________________
# tcn_9 (TCN)                  (None, 128)               473984
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# =================================================================
# Total params: 490,496
# Trainable params: 490,496
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# anchor_input (InputLayer)    [(None, 50, 30, 2, 2)]    0
# _________________________________________________________________
# model_18 (Model)             (None, 128)               490496
# _________________________________________________________________
# dense_19 (Dense)             (None, 3)                 387
# =================================================================
# Total params: 490,883
# Trainable params: 490,883
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 50, 30, 2, 2)]    0
# _________________________________________________________________
# lambda_19 (Lambda)           (None, 50, 120)           0
# _________________________________________________________________
# matching_conv1D (Conv1D)     (None, 50, 128)           15488
# _________________________________________________________________
# activation_191 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           30848
# _________________________________________________________________
# activation_189 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_126 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_190 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_127 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_194 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_192 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_128 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_193 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_129 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_197 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_195 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_130 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_196 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_131 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_200 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_198 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_132 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_199 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_133 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_203 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_201 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_134 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_202 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_135 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_206 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_204 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_136 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_205 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_137 (Spati (None, 50, 128)           0
# _________________________________________________________________
# matching_identity (Lambda)   (None, 50, 128)           0
# _________________________________________________________________
# activation_209 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# conv1D_0 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_207 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_138 (Spati (None, 50, 128)           0
# _________________________________________________________________
# conv1D_1 (Conv1D)            (None, 50, 128)           32896
# _________________________________________________________________
# activation_208 (Activation)  (None, 50, 128)           0
# _________________________________________________________________
# spatial_dropout1d_139 (Spati (None, 50, 128)           0
# _________________________________________________________________
# lambda_9 (Lambda)            (None, 128)               0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# =================================================================
# Total params: 490,496
# Trainable params: 490,496
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training - 10 Frames

# %%
labels_train = K.one_hot(Y_train, nb_classes+1)
labels_val = K.one_hot(Y_val, nb_classes+1)
history = build_triplet.fit(x=X_train, y=labels_train, batch_size=batch_size, epochs=200, verbose=1, callbacks=None, 
                              validation_split=0.02, validation_data=None, shuffle=True, class_weight=None, 
                              sample_weight=None, initial_epoch=0, steps_per_epoch=100, validation_steps=None)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1535fd4a8f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1535fd4a8f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100/100 [==============================] - ETA: 0s - loss: 31.2450 - mean_squared_error: 0.3028 - recall_20: 0.4053 - precision_20: 0.4874 - acc: 0.4656 - categorical_true_positives: 1490.0000WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1535f9c66b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1535f9c66b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100/100 [==============================] - 14s 137ms/step - loss: 31.2450 - mean_squared_error: 0.3028 - recall_20: 0.4053 - precision_20: 0.4874 - acc: 0.4656 - categorical_true_positives: 1490.0000 - val_loss: 29.2807 - val_mean_squared_error: 0.3051 - val_recall_20: 0.5163 - val_precision_20: 0.5217 - val_acc: 0.5210 - val_categorical_true_positives: 559.0000
# Epoch 2/200
# 100/100 [==============================] - 12s 124ms/step - loss: 13.6184 - mean_squared_error: 0.2594 - recall_20: 0.4506 - precision_20: 0.5502 - acc: 0.5713 - categorical_true_positives: 1828.0000 - val_loss: 17.3789 - val_mean_squared_error: 0.2460 - val_recall_20: 0.6021 - val_precision_20: 0.6112 - val_acc: 0.6104 - val_categorical_true_positives: 655.0000
# Epoch 3/200
# 100/100 [==============================] - 12s 123ms/step - loss: 10.4764 - mean_squared_error: 0.2344 - recall_20: 0.4816 - precision_20: 0.5911 - acc: 0.6272 - categorical_true_positives: 2007.0000 - val_loss: 11.4777 - val_mean_squared_error: 0.2048 - val_recall_20: 0.6617 - val_precision_20: 0.6723 - val_acc: 0.6719 - val_categorical_true_positives: 721.0000
# Epoch 4/200
# 100/100 [==============================] - 12s 121ms/step - loss: 8.8090 - mean_squared_error: 0.2168 - recall_20: 0.4975 - precision_20: 0.6233 - acc: 0.6591 - categorical_true_positives: 2109.0000 - val_loss: 11.0931 - val_mean_squared_error: 0.1930 - val_recall_20: 0.6813 - val_precision_20: 0.6922 - val_acc: 0.6915 - val_categorical_true_positives: 742.0000
# Epoch 5/200
# 100/100 [==============================] - 12s 125ms/step - loss: 7.3101 - mean_squared_error: 0.2105 - recall_20: 0.5041 - precision_20: 0.6308 - acc: 0.6603 - categorical_true_positives: 2113.0000 - val_loss: 8.3260 - val_mean_squared_error: 0.1706 - val_recall_20: 0.7176 - val_precision_20: 0.7326 - val_acc: 0.7279 - val_categorical_true_positives: 781.0000
# Epoch 6/200
# 100/100 [==============================] - 12s 121ms/step - loss: 5.6822 - mean_squared_error: 0.2002 - recall_20: 0.5166 - precision_20: 0.6485 - acc: 0.6816 - categorical_true_positives: 2181.0000 - val_loss: 8.0628 - val_mean_squared_error: 0.1613 - val_recall_20: 0.7325 - val_precision_20: 0.7486 - val_acc: 0.7446 - val_categorical_true_positives: 799.0000
# Epoch 7/200
# 100/100 [==============================] - 12s 120ms/step - loss: 5.2355 - mean_squared_error: 0.1899 - recall_20: 0.5200 - precision_20: 0.6595 - acc: 0.6897 - categorical_true_positives: 2207.0000 - val_loss: 7.7591 - val_mean_squared_error: 0.1730 - val_recall_20: 0.7102 - val_precision_20: 0.7271 - val_acc: 0.7195 - val_categorical_true_positives: 772.0000
# Epoch 8/200
# 100/100 [==============================] - 12s 124ms/step - loss: 4.5766 - mean_squared_error: 0.1769 - recall_20: 0.5434 - precision_20: 0.6844 - acc: 0.7113 - categorical_true_positives: 2276.0000 - val_loss: 6.1127 - val_mean_squared_error: 0.1536 - val_recall_20: 0.7390 - val_precision_20: 0.7545 - val_acc: 0.7484 - val_categorical_true_positives: 803.0000
# Epoch 9/200
# 100/100 [==============================] - 12s 121ms/step - loss: 4.5374 - mean_squared_error: 0.1763 - recall_20: 0.5509 - precision_20: 0.6863 - acc: 0.7072 - categorical_true_positives: 2263.0000 - val_loss: 8.7893 - val_mean_squared_error: 0.1883 - val_recall_20: 0.6850 - val_precision_20: 0.6973 - val_acc: 0.6897 - val_categorical_true_positives: 740.0000
# Epoch 10/200
# 100/100 [==============================] - 12s 123ms/step - loss: 4.2821 - mean_squared_error: 0.1731 - recall_20: 0.6003 - precision_20: 0.7024 - acc: 0.7103 - categorical_true_positives: 2273.0000 - val_loss: 5.4386 - val_mean_squared_error: 0.1501 - val_recall_20: 0.7400 - val_precision_20: 0.7540 - val_acc: 0.7474 - val_categorical_true_positives: 802.0000
# Epoch 11/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.7300 - mean_squared_error: 0.1676 - recall_20: 0.6803 - precision_20: 0.7107 - acc: 0.7025 - categorical_true_positives: 2248.0000 - val_loss: 5.0476 - val_mean_squared_error: 0.1467 - val_recall_20: 0.7474 - val_precision_20: 0.7552 - val_acc: 0.7502 - val_categorical_true_positives: 805.0000
# Epoch 12/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.5271 - mean_squared_error: 0.1723 - recall_20: 0.6938 - precision_20: 0.7039 - acc: 0.7000 - categorical_true_positives: 2240.0000 - val_loss: 4.5354 - val_mean_squared_error: 0.1349 - val_recall_20: 0.7670 - val_precision_20: 0.7735 - val_acc: 0.7679 - val_categorical_true_positives: 824.0000
# Epoch 13/200
# 100/100 [==============================] - 12s 124ms/step - loss: 2.8657 - mean_squared_error: 0.1516 - recall_20: 0.7303 - precision_20: 0.7389 - acc: 0.7350 - categorical_true_positives: 2352.0000 - val_loss: 4.3083 - val_mean_squared_error: 0.1338 - val_recall_20: 0.7661 - val_precision_20: 0.7711 - val_acc: 0.7661 - val_categorical_true_positives: 822.0000
# Epoch 14/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.2526 - mean_squared_error: 0.1536 - recall_20: 0.7300 - precision_20: 0.7383 - acc: 0.7350 - categorical_true_positives: 2352.0000 - val_loss: 4.0602 - val_mean_squared_error: 0.1237 - val_recall_20: 0.7847 - val_precision_20: 0.7928 - val_acc: 0.7866 - val_categorical_true_positives: 844.0000
# Epoch 15/200
# 100/100 [==============================] - 12s 123ms/step - loss: 2.7154 - mean_squared_error: 0.1435 - recall_20: 0.7491 - precision_20: 0.7540 - acc: 0.7528 - categorical_true_positives: 2409.0000 - val_loss: 3.8170 - val_mean_squared_error: 0.1269 - val_recall_20: 0.7763 - val_precision_20: 0.7785 - val_acc: 0.7763 - val_categorical_true_positives: 833.0000
# Epoch 16/200
# 100/100 [==============================] - 12s 124ms/step - loss: 2.7500 - mean_squared_error: 0.1448 - recall_20: 0.7441 - precision_20: 0.7492 - acc: 0.7487 - categorical_true_positives: 2396.0000 - val_loss: 3.5182 - val_mean_squared_error: 0.1163 - val_recall_20: 0.7950 - val_precision_20: 0.7965 - val_acc: 0.7950 - val_categorical_true_positives: 853.0000
# Epoch 17/200
# 100/100 [==============================] - 12s 121ms/step - loss: 2.4044 - mean_squared_error: 0.1360 - recall_20: 0.7578 - precision_20: 0.7626 - acc: 0.7600 - categorical_true_positives: 2432.0000 - val_loss: 3.2878 - val_mean_squared_error: 0.1285 - val_recall_20: 0.7726 - val_precision_20: 0.7740 - val_acc: 0.7726 - val_categorical_true_positives: 829.0000
# Epoch 18/200
# 100/100 [==============================] - 13s 126ms/step - loss: 2.1375 - mean_squared_error: 0.1311 - recall_20: 0.7588 - precision_20: 0.7652 - acc: 0.7625 - categorical_true_positives: 2440.0000 - val_loss: 3.1003 - val_mean_squared_error: 0.1116 - val_recall_20: 0.8043 - val_precision_20: 0.8058 - val_acc: 0.8043 - val_categorical_true_positives: 863.0000
# Epoch 19/200
# 100/100 [==============================] - 12s 121ms/step - loss: 2.0174 - mean_squared_error: 0.1272 - recall_20: 0.7669 - precision_20: 0.7722 - acc: 0.7700 - categorical_true_positives: 2464.0000 - val_loss: 2.8534 - val_mean_squared_error: 0.1182 - val_recall_20: 0.7903 - val_precision_20: 0.7925 - val_acc: 0.7903 - val_categorical_true_positives: 848.0000
# Epoch 20/200
# 100/100 [==============================] - 12s 122ms/step - loss: 2.0486 - mean_squared_error: 0.1284 - recall_20: 0.7641 - precision_20: 0.7691 - acc: 0.7669 - categorical_true_positives: 2454.0000 - val_loss: 2.7416 - val_mean_squared_error: 0.1126 - val_recall_20: 0.8015 - val_precision_20: 0.8022 - val_acc: 0.8024 - val_categorical_true_positives: 861.0000
# Epoch 21/200
# 100/100 [==============================] - 12s 123ms/step - loss: 2.0034 - mean_squared_error: 0.1290 - recall_20: 0.7681 - precision_20: 0.7713 - acc: 0.7709 - categorical_true_positives: 2467.0000 - val_loss: 2.5918 - val_mean_squared_error: 0.1209 - val_recall_20: 0.7838 - val_precision_20: 0.7845 - val_acc: 0.7838 - val_categorical_true_positives: 841.0000
# Epoch 22/200
# 100/100 [==============================] - 12s 122ms/step - loss: 1.8017 - mean_squared_error: 0.1250 - recall_20: 0.7691 - precision_20: 0.7712 - acc: 0.7703 - categorical_true_positives: 2465.0000 - val_loss: 2.5368 - val_mean_squared_error: 0.1192 - val_recall_20: 0.7856 - val_precision_20: 0.7871 - val_acc: 0.7856 - val_categorical_true_positives: 843.0000
# Epoch 23/200
# 100/100 [==============================] - 12s 122ms/step - loss: 1.5877 - mean_squared_error: 0.1143 - recall_20: 0.7922 - precision_20: 0.7942 - acc: 0.7934 - categorical_true_positives: 2539.0000 - val_loss: 2.5270 - val_mean_squared_error: 0.1076 - val_recall_20: 0.8015 - val_precision_20: 0.8022 - val_acc: 0.8024 - val_categorical_true_positives: 861.0000
# Epoch 24/200
# 100/100 [==============================] - 12s 123ms/step - loss: 1.7845 - mean_squared_error: 0.1200 - recall_20: 0.7828 - precision_20: 0.7843 - acc: 0.7837 - categorical_true_positives: 2508.0000 - val_loss: 2.4517 - val_mean_squared_error: 0.1102 - val_recall_20: 0.7987 - val_precision_20: 0.7994 - val_acc: 0.7996 - val_categorical_true_positives: 858.0000
# Epoch 25/200
# 100/100 [==============================] - 12s 121ms/step - loss: 1.6463 - mean_squared_error: 0.1186 - recall_20: 0.7781 - precision_20: 0.7806 - acc: 0.7800 - categorical_true_positives: 2496.0000 - val_loss: 2.3752 - val_mean_squared_error: 0.1068 - val_recall_20: 0.8071 - val_precision_20: 0.8078 - val_acc: 0.8071 - val_categorical_true_positives: 866.0000
# Epoch 26/200
# 100/100 [==============================] - 12s 123ms/step - loss: 1.5581 - mean_squared_error: 0.1118 - recall_20: 0.7887 - precision_20: 0.7915 - acc: 0.7903 - categorical_true_positives: 2529.0000 - val_loss: 2.1268 - val_mean_squared_error: 0.1107 - val_recall_20: 0.7987 - val_precision_20: 0.8002 - val_acc: 0.8006 - val_categorical_true_positives: 859.0000
# Epoch 27/200
# 100/100 [==============================] - 12s 120ms/step - loss: 1.4860 - mean_squared_error: 0.1078 - recall_20: 0.7994 - precision_20: 0.8019 - acc: 0.8012 - categorical_true_positives: 2564.0000 - val_loss: 2.1266 - val_mean_squared_error: 0.1108 - val_recall_20: 0.7968 - val_precision_20: 0.7976 - val_acc: 0.7978 - val_categorical_true_positives: 856.0000
# Epoch 28/200
# 100/100 [==============================] - 12s 124ms/step - loss: 1.4222 - mean_squared_error: 0.1072 - recall_20: 0.7978 - precision_20: 0.8001 - acc: 0.7991 - categorical_true_positives: 2557.0000 - val_loss: 2.0173 - val_mean_squared_error: 0.1099 - val_recall_20: 0.7987 - val_precision_20: 0.8002 - val_acc: 0.7996 - val_categorical_true_positives: 858.0000
# Epoch 29/200
# 100/100 [==============================] - 12s 121ms/step - loss: 1.3776 - mean_squared_error: 0.1049 - recall_20: 0.8037 - precision_20: 0.8068 - acc: 0.8056 - categorical_true_positives: 2578.0000 - val_loss: 1.9273 - val_mean_squared_error: 0.1095 - val_recall_20: 0.7978 - val_precision_20: 0.7985 - val_acc: 0.7987 - val_categorical_true_positives: 857.0000
# Epoch 30/200
# 100/100 [==============================] - 12s 123ms/step - loss: 1.2509 - mean_squared_error: 0.1046 - recall_20: 0.7997 - precision_20: 0.8014 - acc: 0.8006 - categorical_true_positives: 2562.0000 - val_loss: 1.8215 - val_mean_squared_error: 0.1049 - val_recall_20: 0.8024 - val_precision_20: 0.8032 - val_acc: 0.8034 - val_categorical_true_positives: 862.0000
# Epoch 31/200
# 100/100 [==============================] - 12s 121ms/step - loss: 1.3992 - mean_squared_error: 0.1077 - recall_20: 0.7937 - precision_20: 0.7950 - acc: 0.7937 - categorical_true_positives: 2540.0000 - val_loss: 1.9013 - val_mean_squared_error: 0.0947 - val_recall_20: 0.8220 - val_precision_20: 0.8228 - val_acc: 0.8220 - val_categorical_true_positives: 882.0000
# Epoch 32/200
# 100/100 [==============================] - 12s 124ms/step - loss: 1.3278 - mean_squared_error: 0.1022 - recall_20: 0.8053 - precision_20: 0.8073 - acc: 0.8059 - categorical_true_positives: 2579.0000 - val_loss: 1.6613 - val_mean_squared_error: 0.0973 - val_recall_20: 0.8145 - val_precision_20: 0.8161 - val_acc: 0.8155 - val_categorical_true_positives: 875.0000
# Epoch 33/200
# 100/100 [==============================] - 12s 123ms/step - loss: 1.2341 - mean_squared_error: 0.0963 - recall_20: 0.8159 - precision_20: 0.8180 - acc: 0.8169 - categorical_true_positives: 2614.0000 - val_loss: 1.8181 - val_mean_squared_error: 0.0950 - val_recall_20: 0.8145 - val_precision_20: 0.8161 - val_acc: 0.8164 - val_categorical_true_positives: 876.0000
# Epoch 34/200
# 100/100 [==============================] - 12s 121ms/step - loss: 1.1918 - mean_squared_error: 0.0979 - recall_20: 0.8134 - precision_20: 0.8150 - acc: 0.8134 - categorical_true_positives: 2603.0000 - val_loss: 1.6026 - val_mean_squared_error: 0.0928 - val_recall_20: 0.8220 - val_precision_20: 0.8235 - val_acc: 0.8229 - val_categorical_true_positives: 883.0000
# Epoch 35/200
# 100/100 [==============================] - 12s 123ms/step - loss: 1.1403 - mean_squared_error: 0.0965 - recall_20: 0.8166 - precision_20: 0.8178 - acc: 0.8172 - categorical_true_positives: 2615.0000 - val_loss: 1.7154 - val_mean_squared_error: 0.0895 - val_recall_20: 0.8295 - val_precision_20: 0.8318 - val_acc: 0.8313 - val_categorical_true_positives: 892.0000
# Epoch 36/200
# 100/100 [==============================] - 12s 119ms/step - loss: 1.1049 - mean_squared_error: 0.0951 - recall_20: 0.8156 - precision_20: 0.8164 - acc: 0.8159 - categorical_true_positives: 2611.0000 - val_loss: 1.4113 - val_mean_squared_error: 0.0857 - val_recall_20: 0.8341 - val_precision_20: 0.8357 - val_acc: 0.8350 - val_categorical_true_positives: 896.0000
# Epoch 37/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.9773 - mean_squared_error: 0.0876 - recall_20: 0.8325 - precision_20: 0.8343 - acc: 0.8338 - categorical_true_positives: 2668.0000 - val_loss: 1.3765 - val_mean_squared_error: 0.0828 - val_recall_20: 0.8406 - val_precision_20: 0.8406 - val_acc: 0.8406 - val_categorical_true_positives: 902.0000
# Epoch 38/200
# 100/100 [==============================] - 12s 122ms/step - loss: 1.1230 - mean_squared_error: 0.0871 - recall_20: 0.8347 - precision_20: 0.8357 - acc: 0.8350 - categorical_true_positives: 2672.0000 - val_loss: 1.3392 - val_mean_squared_error: 0.0894 - val_recall_20: 0.8304 - val_precision_20: 0.8312 - val_acc: 0.8313 - val_categorical_true_positives: 892.0000
# Epoch 39/200
# 100/100 [==============================] - 12s 123ms/step - loss: 1.0024 - mean_squared_error: 0.0897 - recall_20: 0.8259 - precision_20: 0.8265 - acc: 0.8259 - categorical_true_positives: 2643.0000 - val_loss: 1.4183 - val_mean_squared_error: 0.0786 - val_recall_20: 0.8546 - val_precision_20: 0.8562 - val_acc: 0.8555 - val_categorical_true_positives: 918.0000
# Epoch 40/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.9842 - mean_squared_error: 0.0850 - recall_20: 0.8391 - precision_20: 0.8398 - acc: 0.8400 - categorical_true_positives: 2688.0000 - val_loss: 1.3506 - val_mean_squared_error: 0.0804 - val_recall_20: 0.8527 - val_precision_20: 0.8543 - val_acc: 0.8537 - val_categorical_true_positives: 916.0000
# Epoch 41/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.8638 - mean_squared_error: 0.0844 - recall_20: 0.8338 - precision_20: 0.8353 - acc: 0.8350 - categorical_true_positives: 2672.0000 - val_loss: 1.2571 - val_mean_squared_error: 0.0816 - val_recall_20: 0.8509 - val_precision_20: 0.8517 - val_acc: 0.8518 - val_categorical_true_positives: 914.0000
# Epoch 42/200
# 100/100 [==============================] - 12s 124ms/step - loss: 0.9300 - mean_squared_error: 0.0860 - recall_20: 0.8356 - precision_20: 0.8372 - acc: 0.8366 - categorical_true_positives: 2677.0000 - val_loss: 1.2913 - val_mean_squared_error: 0.0859 - val_recall_20: 0.8397 - val_precision_20: 0.8397 - val_acc: 0.8397 - val_categorical_true_positives: 901.0000
# Epoch 43/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.9031 - mean_squared_error: 0.0816 - recall_20: 0.8456 - precision_20: 0.8462 - acc: 0.8462 - categorical_true_positives: 2708.0000 - val_loss: 1.3706 - val_mean_squared_error: 0.0738 - val_recall_20: 0.8649 - val_precision_20: 0.8649 - val_acc: 0.8649 - val_categorical_true_positives: 928.0000
# Epoch 44/200
# 100/100 [==============================] - 12s 125ms/step - loss: 0.8765 - mean_squared_error: 0.0817 - recall_20: 0.8428 - precision_20: 0.8444 - acc: 0.8438 - categorical_true_positives: 2700.0000 - val_loss: 1.3422 - val_mean_squared_error: 0.0727 - val_recall_20: 0.8658 - val_precision_20: 0.8658 - val_acc: 0.8658 - val_categorical_true_positives: 929.0000
# Epoch 45/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.8396 - mean_squared_error: 0.0794 - recall_20: 0.8512 - precision_20: 0.8518 - acc: 0.8516 - categorical_true_positives: 2725.0000 - val_loss: 1.1201 - val_mean_squared_error: 0.0704 - val_recall_20: 0.8667 - val_precision_20: 0.8667 - val_acc: 0.8667 - val_categorical_true_positives: 930.0000
# Epoch 46/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.8757 - mean_squared_error: 0.0816 - recall_20: 0.8500 - precision_20: 0.8503 - acc: 0.8503 - categorical_true_positives: 2721.0000 - val_loss: 1.2431 - val_mean_squared_error: 0.0706 - val_recall_20: 0.8705 - val_precision_20: 0.8713 - val_acc: 0.8714 - val_categorical_true_positives: 935.0000
# Epoch 47/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.7958 - mean_squared_error: 0.0717 - recall_20: 0.8628 - precision_20: 0.8631 - acc: 0.8631 - categorical_true_positives: 2762.0000 - val_loss: 1.0497 - val_mean_squared_error: 0.0717 - val_recall_20: 0.8658 - val_precision_20: 0.8666 - val_acc: 0.8658 - val_categorical_true_positives: 929.0000
# Epoch 48/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.8042 - mean_squared_error: 0.0729 - recall_20: 0.8616 - precision_20: 0.8624 - acc: 0.8622 - categorical_true_positives: 2759.0000 - val_loss: 1.0047 - val_mean_squared_error: 0.0690 - val_recall_20: 0.8686 - val_precision_20: 0.8686 - val_acc: 0.8686 - val_categorical_true_positives: 932.0000
# Epoch 49/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.8241 - mean_squared_error: 0.0734 - recall_20: 0.8634 - precision_20: 0.8651 - acc: 0.8641 - categorical_true_positives: 2765.0000 - val_loss: 1.0702 - val_mean_squared_error: 0.0654 - val_recall_20: 0.8760 - val_precision_20: 0.8760 - val_acc: 0.8760 - val_categorical_true_positives: 940.0000
# Epoch 50/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.8029 - mean_squared_error: 0.0741 - recall_20: 0.8594 - precision_20: 0.8605 - acc: 0.8606 - categorical_true_positives: 2754.0000 - val_loss: 1.0013 - val_mean_squared_error: 0.0672 - val_recall_20: 0.8760 - val_precision_20: 0.8760 - val_acc: 0.8760 - val_categorical_true_positives: 940.0000
# Epoch 51/200
# 100/100 [==============================] - 13s 126ms/step - loss: 0.7838 - mean_squared_error: 0.0703 - recall_20: 0.8684 - precision_20: 0.8695 - acc: 0.8691 - categorical_true_positives: 2781.0000 - val_loss: 1.0774 - val_mean_squared_error: 0.0671 - val_recall_20: 0.8779 - val_precision_20: 0.8779 - val_acc: 0.8779 - val_categorical_true_positives: 942.0000
# Epoch 52/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6959 - mean_squared_error: 0.0628 - recall_20: 0.8809 - precision_20: 0.8826 - acc: 0.8816 - categorical_true_positives: 2821.0000 - val_loss: 0.9734 - val_mean_squared_error: 0.0707 - val_recall_20: 0.8714 - val_precision_20: 0.8722 - val_acc: 0.8723 - val_categorical_true_positives: 936.0000
# Epoch 53/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.7328 - mean_squared_error: 0.0675 - recall_20: 0.8703 - precision_20: 0.8709 - acc: 0.8706 - categorical_true_positives: 2786.0000 - val_loss: 1.0354 - val_mean_squared_error: 0.0652 - val_recall_20: 0.8807 - val_precision_20: 0.8807 - val_acc: 0.8807 - val_categorical_true_positives: 945.0000
# Epoch 54/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6845 - mean_squared_error: 0.0606 - recall_20: 0.8850 - precision_20: 0.8853 - acc: 0.8850 - categorical_true_positives: 2832.0000 - val_loss: 0.9134 - val_mean_squared_error: 0.0619 - val_recall_20: 0.8798 - val_precision_20: 0.8798 - val_acc: 0.8798 - val_categorical_true_positives: 944.0000
# Epoch 55/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6943 - mean_squared_error: 0.0643 - recall_20: 0.8831 - precision_20: 0.8842 - acc: 0.8831 - categorical_true_positives: 2826.0000 - val_loss: 0.9008 - val_mean_squared_error: 0.0631 - val_recall_20: 0.8826 - val_precision_20: 0.8826 - val_acc: 0.8826 - val_categorical_true_positives: 947.0000
# Epoch 56/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6694 - mean_squared_error: 0.0624 - recall_20: 0.8866 - precision_20: 0.8871 - acc: 0.8866 - categorical_true_positives: 2837.0000 - val_loss: 0.9038 - val_mean_squared_error: 0.0624 - val_recall_20: 0.8816 - val_precision_20: 0.8825 - val_acc: 0.8826 - val_categorical_true_positives: 947.0000
# Epoch 57/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6609 - mean_squared_error: 0.0619 - recall_20: 0.8853 - precision_20: 0.8864 - acc: 0.8863 - categorical_true_positives: 2836.0000 - val_loss: 0.9231 - val_mean_squared_error: 0.0602 - val_recall_20: 0.8863 - val_precision_20: 0.8871 - val_acc: 0.8872 - val_categorical_true_positives: 952.0000
# Epoch 58/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6330 - mean_squared_error: 0.0601 - recall_20: 0.8853 - precision_20: 0.8864 - acc: 0.8863 - categorical_true_positives: 2836.0000 - val_loss: 0.8902 - val_mean_squared_error: 0.0571 - val_recall_20: 0.8947 - val_precision_20: 0.8947 - val_acc: 0.8947 - val_categorical_true_positives: 960.0000
# Epoch 59/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.6424 - mean_squared_error: 0.0595 - recall_20: 0.8894 - precision_20: 0.8894 - acc: 0.8894 - categorical_true_positives: 2846.0000 - val_loss: 0.8438 - val_mean_squared_error: 0.0553 - val_recall_20: 0.8947 - val_precision_20: 0.8947 - val_acc: 0.8947 - val_categorical_true_positives: 960.0000
# Epoch 60/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.5903 - mean_squared_error: 0.0573 - recall_20: 0.8897 - precision_20: 0.8900 - acc: 0.8897 - categorical_true_positives: 2847.0000 - val_loss: 0.7538 - val_mean_squared_error: 0.0536 - val_recall_20: 0.8984 - val_precision_20: 0.8984 - val_acc: 0.8984 - val_categorical_true_positives: 964.0000
# Epoch 61/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.6342 - mean_squared_error: 0.0555 - recall_20: 0.8991 - precision_20: 0.8991 - acc: 0.8991 - categorical_true_positives: 2877.0000 - val_loss: 0.7519 - val_mean_squared_error: 0.0521 - val_recall_20: 0.9021 - val_precision_20: 0.9021 - val_acc: 0.9021 - val_categorical_true_positives: 968.0000
# Epoch 62/200
# 100/100 [==============================] - 12s 125ms/step - loss: 0.6259 - mean_squared_error: 0.0548 - recall_20: 0.8966 - precision_20: 0.8968 - acc: 0.8969 - categorical_true_positives: 2870.0000 - val_loss: 0.7315 - val_mean_squared_error: 0.0467 - val_recall_20: 0.9105 - val_precision_20: 0.9105 - val_acc: 0.9105 - val_categorical_true_positives: 977.0000
# Epoch 63/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.5941 - mean_squared_error: 0.0546 - recall_20: 0.8922 - precision_20: 0.8927 - acc: 0.8925 - categorical_true_positives: 2856.0000 - val_loss: 0.7301 - val_mean_squared_error: 0.0590 - val_recall_20: 0.8910 - val_precision_20: 0.8910 - val_acc: 0.8910 - val_categorical_true_positives: 956.0000
# Epoch 64/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.6363 - mean_squared_error: 0.0568 - recall_20: 0.8928 - precision_20: 0.8928 - acc: 0.8928 - categorical_true_positives: 2857.0000 - val_loss: 0.7541 - val_mean_squared_error: 0.0454 - val_recall_20: 0.9124 - val_precision_20: 0.9141 - val_acc: 0.9133 - val_categorical_true_positives: 980.0000
# Epoch 65/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.5674 - mean_squared_error: 0.0475 - recall_20: 0.9103 - precision_20: 0.9106 - acc: 0.9103 - categorical_true_positives: 2913.0000 - val_loss: 0.6360 - val_mean_squared_error: 0.0448 - val_recall_20: 0.9133 - val_precision_20: 0.9133 - val_acc: 0.9133 - val_categorical_true_positives: 980.0000
# Epoch 66/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.6026 - mean_squared_error: 0.0511 - recall_20: 0.9053 - precision_20: 0.9053 - acc: 0.9053 - categorical_true_positives: 2897.0000 - val_loss: 0.6961 - val_mean_squared_error: 0.0434 - val_recall_20: 0.9171 - val_precision_20: 0.9171 - val_acc: 0.9171 - val_categorical_true_positives: 984.0000
# Epoch 67/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.5732 - mean_squared_error: 0.0515 - recall_20: 0.8984 - precision_20: 0.8990 - acc: 0.8991 - categorical_true_positives: 2877.0000 - val_loss: 0.6649 - val_mean_squared_error: 0.0506 - val_recall_20: 0.9049 - val_precision_20: 0.9058 - val_acc: 0.9049 - val_categorical_true_positives: 971.0000
# Epoch 68/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.5286 - mean_squared_error: 0.0466 - recall_20: 0.9081 - precision_20: 0.9081 - acc: 0.9081 - categorical_true_positives: 2906.0000 - val_loss: 0.6753 - val_mean_squared_error: 0.0433 - val_recall_20: 0.9199 - val_precision_20: 0.9199 - val_acc: 0.9199 - val_categorical_true_positives: 987.0000
# Epoch 69/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.5343 - mean_squared_error: 0.0460 - recall_20: 0.9153 - precision_20: 0.9159 - acc: 0.9156 - categorical_true_positives: 2930.0000 - val_loss: 0.6480 - val_mean_squared_error: 0.0480 - val_recall_20: 0.9105 - val_precision_20: 0.9105 - val_acc: 0.9105 - val_categorical_true_positives: 977.0000
# Epoch 70/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.5375 - mean_squared_error: 0.0456 - recall_20: 0.9106 - precision_20: 0.9115 - acc: 0.9116 - categorical_true_positives: 2917.0000 - val_loss: 0.6263 - val_mean_squared_error: 0.0418 - val_recall_20: 0.9208 - val_precision_20: 0.9208 - val_acc: 0.9208 - val_categorical_true_positives: 988.0000
# Epoch 71/200
# 100/100 [==============================] - 12s 119ms/step - loss: 0.5612 - mean_squared_error: 0.0472 - recall_20: 0.9112 - precision_20: 0.9112 - acc: 0.9112 - categorical_true_positives: 2916.0000 - val_loss: 0.6387 - val_mean_squared_error: 0.0413 - val_recall_20: 0.9245 - val_precision_20: 0.9245 - val_acc: 0.9245 - val_categorical_true_positives: 992.0000
# Epoch 72/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.5181 - mean_squared_error: 0.0427 - recall_20: 0.9200 - precision_20: 0.9200 - acc: 0.9200 - categorical_true_positives: 2944.0000 - val_loss: 0.6705 - val_mean_squared_error: 0.0406 - val_recall_20: 0.9245 - val_precision_20: 0.9245 - val_acc: 0.9245 - val_categorical_true_positives: 992.0000
# Epoch 73/200
# 100/100 [==============================] - 12s 125ms/step - loss: 0.5101 - mean_squared_error: 0.0401 - recall_20: 0.9237 - precision_20: 0.9240 - acc: 0.9241 - categorical_true_positives: 2957.0000 - val_loss: 0.6296 - val_mean_squared_error: 0.0381 - val_recall_20: 0.9273 - val_precision_20: 0.9273 - val_acc: 0.9273 - val_categorical_true_positives: 995.0000
# Epoch 74/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.5069 - mean_squared_error: 0.0401 - recall_20: 0.9225 - precision_20: 0.9228 - acc: 0.9225 - categorical_true_positives: 2952.0000 - val_loss: 0.6897 - val_mean_squared_error: 0.0369 - val_recall_20: 0.9282 - val_precision_20: 0.9282 - val_acc: 0.9282 - val_categorical_true_positives: 996.0000
# Epoch 75/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4974 - mean_squared_error: 0.0407 - recall_20: 0.9197 - precision_20: 0.9197 - acc: 0.9197 - categorical_true_positives: 2943.0000 - val_loss: 0.8584 - val_mean_squared_error: 0.0461 - val_recall_20: 0.9105 - val_precision_20: 0.9105 - val_acc: 0.9105 - val_categorical_true_positives: 977.0000
# Epoch 76/200
# 100/100 [==============================] - 12s 124ms/step - loss: 0.5299 - mean_squared_error: 0.0416 - recall_20: 0.9206 - precision_20: 0.9206 - acc: 0.9206 - categorical_true_positives: 2946.0000 - val_loss: 0.5980 - val_mean_squared_error: 0.0373 - val_recall_20: 0.9264 - val_precision_20: 0.9264 - val_acc: 0.9264 - val_categorical_true_positives: 994.0000
# Epoch 77/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4857 - mean_squared_error: 0.0387 - recall_20: 0.9219 - precision_20: 0.9225 - acc: 0.9222 - categorical_true_positives: 2951.0000 - val_loss: 0.7104 - val_mean_squared_error: 0.0391 - val_recall_20: 0.9254 - val_precision_20: 0.9254 - val_acc: 0.9254 - val_categorical_true_positives: 993.0000
# Epoch 78/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4516 - mean_squared_error: 0.0347 - recall_20: 0.9303 - precision_20: 0.9303 - acc: 0.9303 - categorical_true_positives: 2977.0000 - val_loss: 0.5863 - val_mean_squared_error: 0.0382 - val_recall_20: 0.9245 - val_precision_20: 0.9245 - val_acc: 0.9245 - val_categorical_true_positives: 992.0000
# Epoch 79/200
# 100/100 [==============================] - 12s 119ms/step - loss: 0.4764 - mean_squared_error: 0.0361 - recall_20: 0.9253 - precision_20: 0.9253 - acc: 0.9253 - categorical_true_positives: 2961.0000 - val_loss: 0.5770 - val_mean_squared_error: 0.0342 - val_recall_20: 0.9320 - val_precision_20: 0.9320 - val_acc: 0.9320 - val_categorical_true_positives: 1000.0000
# Epoch 80/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4670 - mean_squared_error: 0.0337 - recall_20: 0.9306 - precision_20: 0.9306 - acc: 0.9306 - categorical_true_positives: 2978.0000 - val_loss: 0.6402 - val_mean_squared_error: 0.0349 - val_recall_20: 0.9301 - val_precision_20: 0.9301 - val_acc: 0.9301 - val_categorical_true_positives: 998.0000
# Epoch 81/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4531 - mean_squared_error: 0.0315 - recall_20: 0.9394 - precision_20: 0.9394 - acc: 0.9394 - categorical_true_positives: 3006.0000 - val_loss: 0.5587 - val_mean_squared_error: 0.0345 - val_recall_20: 0.9273 - val_precision_20: 0.9273 - val_acc: 0.9273 - val_categorical_true_positives: 995.0000
# Epoch 82/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4589 - mean_squared_error: 0.0323 - recall_20: 0.9347 - precision_20: 0.9347 - acc: 0.9347 - categorical_true_positives: 2991.0000 - val_loss: 0.5614 - val_mean_squared_error: 0.0330 - val_recall_20: 0.9273 - val_precision_20: 0.9273 - val_acc: 0.9273 - val_categorical_true_positives: 995.0000
# Epoch 83/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.4252 - mean_squared_error: 0.0295 - recall_20: 0.9391 - precision_20: 0.9391 - acc: 0.9391 - categorical_true_positives: 3005.0000 - val_loss: 0.5990 - val_mean_squared_error: 0.0325 - val_recall_20: 0.9338 - val_precision_20: 0.9338 - val_acc: 0.9338 - val_categorical_true_positives: 1002.0000
# Epoch 84/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4392 - mean_squared_error: 0.0304 - recall_20: 0.9388 - precision_20: 0.9390 - acc: 0.9388 - categorical_true_positives: 3004.0000 - val_loss: 0.5644 - val_mean_squared_error: 0.0318 - val_recall_20: 0.9348 - val_precision_20: 0.9348 - val_acc: 0.9348 - val_categorical_true_positives: 1003.0000
# Epoch 85/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4003 - mean_squared_error: 0.0253 - recall_20: 0.9481 - precision_20: 0.9487 - acc: 0.9484 - categorical_true_positives: 3035.0000 - val_loss: 0.5530 - val_mean_squared_error: 0.0344 - val_recall_20: 0.9320 - val_precision_20: 0.9320 - val_acc: 0.9320 - val_categorical_true_positives: 1000.0000
# Epoch 86/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4268 - mean_squared_error: 0.0297 - recall_20: 0.9359 - precision_20: 0.9359 - acc: 0.9359 - categorical_true_positives: 2995.0000 - val_loss: 0.5301 - val_mean_squared_error: 0.0287 - val_recall_20: 0.9422 - val_precision_20: 0.9422 - val_acc: 0.9422 - val_categorical_true_positives: 1011.0000
# Epoch 87/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3851 - mean_squared_error: 0.0220 - recall_20: 0.9578 - precision_20: 0.9584 - acc: 0.9581 - categorical_true_positives: 3066.0000 - val_loss: 0.6212 - val_mean_squared_error: 0.0290 - val_recall_20: 0.9441 - val_precision_20: 0.9441 - val_acc: 0.9441 - val_categorical_true_positives: 1013.0000
# Epoch 88/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3962 - mean_squared_error: 0.0233 - recall_20: 0.9531 - precision_20: 0.9531 - acc: 0.9531 - categorical_true_positives: 3050.0000 - val_loss: 0.6857 - val_mean_squared_error: 0.0296 - val_recall_20: 0.9413 - val_precision_20: 0.9413 - val_acc: 0.9413 - val_categorical_true_positives: 1010.0000
# Epoch 89/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.4085 - mean_squared_error: 0.0229 - recall_20: 0.9563 - precision_20: 0.9563 - acc: 0.9563 - categorical_true_positives: 3060.0000 - val_loss: 0.5818 - val_mean_squared_error: 0.0260 - val_recall_20: 0.9487 - val_precision_20: 0.9487 - val_acc: 0.9487 - val_categorical_true_positives: 1018.0000
# Epoch 90/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.4051 - mean_squared_error: 0.0246 - recall_20: 0.9500 - precision_20: 0.9503 - acc: 0.9500 - categorical_true_positives: 3040.0000 - val_loss: 0.5278 - val_mean_squared_error: 0.0280 - val_recall_20: 0.9413 - val_precision_20: 0.9413 - val_acc: 0.9413 - val_categorical_true_positives: 1010.0000
# Epoch 91/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3741 - mean_squared_error: 0.0206 - recall_20: 0.9550 - precision_20: 0.9553 - acc: 0.9553 - categorical_true_positives: 3057.0000 - val_loss: 0.5475 - val_mean_squared_error: 0.0245 - val_recall_20: 0.9525 - val_precision_20: 0.9525 - val_acc: 0.9525 - val_categorical_true_positives: 1022.0000
# Epoch 92/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3674 - mean_squared_error: 0.0176 - recall_20: 0.9650 - precision_20: 0.9653 - acc: 0.9653 - categorical_true_positives: 3089.0000 - val_loss: 0.5313 - val_mean_squared_error: 0.0225 - val_recall_20: 0.9553 - val_precision_20: 0.9553 - val_acc: 0.9553 - val_categorical_true_positives: 1025.0000
# Epoch 93/200
# 100/100 [==============================] - 13s 125ms/step - loss: 0.3782 - mean_squared_error: 0.0198 - recall_20: 0.9628 - precision_20: 0.9634 - acc: 0.9631 - categorical_true_positives: 3082.0000 - val_loss: 0.4877 - val_mean_squared_error: 0.0234 - val_recall_20: 0.9534 - val_precision_20: 0.9534 - val_acc: 0.9534 - val_categorical_true_positives: 1023.0000
# Epoch 94/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3649 - mean_squared_error: 0.0195 - recall_20: 0.9634 - precision_20: 0.9640 - acc: 0.9641 - categorical_true_positives: 3085.0000 - val_loss: 0.4966 - val_mean_squared_error: 0.0223 - val_recall_20: 0.9543 - val_precision_20: 0.9543 - val_acc: 0.9543 - val_categorical_true_positives: 1024.0000
# Epoch 95/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3677 - mean_squared_error: 0.0193 - recall_20: 0.9628 - precision_20: 0.9628 - acc: 0.9628 - categorical_true_positives: 3081.0000 - val_loss: 0.4528 - val_mean_squared_error: 0.0216 - val_recall_20: 0.9543 - val_precision_20: 0.9543 - val_acc: 0.9543 - val_categorical_true_positives: 1024.0000
# Epoch 96/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.3565 - mean_squared_error: 0.0175 - recall_20: 0.9678 - precision_20: 0.9678 - acc: 0.9678 - categorical_true_positives: 3097.0000 - val_loss: 0.5357 - val_mean_squared_error: 0.0239 - val_recall_20: 0.9515 - val_precision_20: 0.9515 - val_acc: 0.9515 - val_categorical_true_positives: 1021.0000
# Epoch 97/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3517 - mean_squared_error: 0.0166 - recall_20: 0.9684 - precision_20: 0.9687 - acc: 0.9688 - categorical_true_positives: 3100.0000 - val_loss: 0.5794 - val_mean_squared_error: 0.0229 - val_recall_20: 0.9562 - val_precision_20: 0.9562 - val_acc: 0.9562 - val_categorical_true_positives: 1026.0000
# Epoch 98/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3766 - mean_squared_error: 0.0183 - recall_20: 0.9681 - precision_20: 0.9684 - acc: 0.9681 - categorical_true_positives: 3098.0000 - val_loss: 0.6035 - val_mean_squared_error: 0.0225 - val_recall_20: 0.9581 - val_precision_20: 0.9581 - val_acc: 0.9581 - val_categorical_true_positives: 1028.0000
# Epoch 99/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.3779 - mean_squared_error: 0.0181 - recall_20: 0.9678 - precision_20: 0.9681 - acc: 0.9678 - categorical_true_positives: 3097.0000 - val_loss: 0.4117 - val_mean_squared_error: 0.0197 - val_recall_20: 0.9571 - val_precision_20: 0.9571 - val_acc: 0.9571 - val_categorical_true_positives: 1027.0000
# Epoch 100/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.3360 - mean_squared_error: 0.0135 - recall_20: 0.9750 - precision_20: 0.9753 - acc: 0.9750 - categorical_true_positives: 3120.0000 - val_loss: 0.4679 - val_mean_squared_error: 0.0202 - val_recall_20: 0.9609 - val_precision_20: 0.9609 - val_acc: 0.9609 - val_categorical_true_positives: 1031.0000
# Epoch 101/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.3541 - mean_squared_error: 0.0168 - recall_20: 0.9691 - precision_20: 0.9691 - acc: 0.9691 - categorical_true_positives: 3101.0000 - val_loss: 0.4621 - val_mean_squared_error: 0.0201 - val_recall_20: 0.9609 - val_precision_20: 0.9609 - val_acc: 0.9609 - val_categorical_true_positives: 1031.0000
# Epoch 102/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.3400 - mean_squared_error: 0.0142 - recall_20: 0.9734 - precision_20: 0.9737 - acc: 0.9737 - categorical_true_positives: 3116.0000 - val_loss: 0.4932 - val_mean_squared_error: 0.0212 - val_recall_20: 0.9618 - val_precision_20: 0.9627 - val_acc: 0.9627 - val_categorical_true_positives: 1033.0000
# Epoch 103/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3288 - mean_squared_error: 0.0137 - recall_20: 0.9766 - precision_20: 0.9766 - acc: 0.9766 - categorical_true_positives: 3125.0000 - val_loss: 0.4622 - val_mean_squared_error: 0.0196 - val_recall_20: 0.9646 - val_precision_20: 0.9655 - val_acc: 0.9646 - val_categorical_true_positives: 1035.0000
# Epoch 104/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3143 - mean_squared_error: 0.0114 - recall_20: 0.9803 - precision_20: 0.9803 - acc: 0.9803 - categorical_true_positives: 3137.0000 - val_loss: 0.6109 - val_mean_squared_error: 0.0240 - val_recall_20: 0.9581 - val_precision_20: 0.9581 - val_acc: 0.9581 - val_categorical_true_positives: 1028.0000
# Epoch 105/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3223 - mean_squared_error: 0.0122 - recall_20: 0.9759 - precision_20: 0.9759 - acc: 0.9759 - categorical_true_positives: 3123.0000 - val_loss: 0.5151 - val_mean_squared_error: 0.0205 - val_recall_20: 0.9637 - val_precision_20: 0.9637 - val_acc: 0.9637 - val_categorical_true_positives: 1034.0000
# Epoch 106/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3169 - mean_squared_error: 0.0100 - recall_20: 0.9825 - precision_20: 0.9825 - acc: 0.9825 - categorical_true_positives: 3144.0000 - val_loss: 0.4886 - val_mean_squared_error: 0.0200 - val_recall_20: 0.9646 - val_precision_20: 0.9646 - val_acc: 0.9646 - val_categorical_true_positives: 1035.0000
# Epoch 107/200
# 100/100 [==============================] - 12s 124ms/step - loss: 0.3261 - mean_squared_error: 0.0122 - recall_20: 0.9756 - precision_20: 0.9756 - acc: 0.9756 - categorical_true_positives: 3122.0000 - val_loss: 0.3824 - val_mean_squared_error: 0.0200 - val_recall_20: 0.9599 - val_precision_20: 0.9599 - val_acc: 0.9599 - val_categorical_true_positives: 1030.0000
# Epoch 108/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3167 - mean_squared_error: 0.0113 - recall_20: 0.9791 - precision_20: 0.9791 - acc: 0.9791 - categorical_true_positives: 3133.0000 - val_loss: 0.7473 - val_mean_squared_error: 0.0291 - val_recall_20: 0.9525 - val_precision_20: 0.9525 - val_acc: 0.9525 - val_categorical_true_positives: 1022.0000
# Epoch 109/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3537 - mean_squared_error: 0.0139 - recall_20: 0.9750 - precision_20: 0.9750 - acc: 0.9750 - categorical_true_positives: 3120.0000 - val_loss: 0.5889 - val_mean_squared_error: 0.0215 - val_recall_20: 0.9637 - val_precision_20: 0.9637 - val_acc: 0.9637 - val_categorical_true_positives: 1034.0000
# Epoch 110/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3086 - mean_squared_error: 0.0095 - recall_20: 0.9822 - precision_20: 0.9822 - acc: 0.9822 - categorical_true_positives: 3143.0000 - val_loss: 0.4938 - val_mean_squared_error: 0.0200 - val_recall_20: 0.9664 - val_precision_20: 0.9664 - val_acc: 0.9664 - val_categorical_true_positives: 1037.0000
# Epoch 111/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3166 - mean_squared_error: 0.0096 - recall_20: 0.9825 - precision_20: 0.9825 - acc: 0.9825 - categorical_true_positives: 3144.0000 - val_loss: 0.3734 - val_mean_squared_error: 0.0155 - val_recall_20: 0.9739 - val_precision_20: 0.9739 - val_acc: 0.9739 - val_categorical_true_positives: 1045.0000
# Epoch 112/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3007 - mean_squared_error: 0.0090 - recall_20: 0.9828 - precision_20: 0.9828 - acc: 0.9828 - categorical_true_positives: 3145.0000 - val_loss: 0.3548 - val_mean_squared_error: 0.0143 - val_recall_20: 0.9739 - val_precision_20: 0.9748 - val_acc: 0.9739 - val_categorical_true_positives: 1045.0000
# Epoch 113/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.3031 - mean_squared_error: 0.0104 - recall_20: 0.9812 - precision_20: 0.9812 - acc: 0.9812 - categorical_true_positives: 3140.0000 - val_loss: 0.4006 - val_mean_squared_error: 0.0159 - val_recall_20: 0.9730 - val_precision_20: 0.9730 - val_acc: 0.9730 - val_categorical_true_positives: 1044.0000
# Epoch 114/200
# 100/100 [==============================] - 12s 119ms/step - loss: 0.3153 - mean_squared_error: 0.0106 - recall_20: 0.9794 - precision_20: 0.9794 - acc: 0.9794 - categorical_true_positives: 3134.0000 - val_loss: 0.3593 - val_mean_squared_error: 0.0142 - val_recall_20: 0.9748 - val_precision_20: 0.9748 - val_acc: 0.9748 - val_categorical_true_positives: 1046.0000
# Epoch 115/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.3179 - mean_squared_error: 0.0099 - recall_20: 0.9831 - precision_20: 0.9831 - acc: 0.9831 - categorical_true_positives: 3146.0000 - val_loss: 0.4088 - val_mean_squared_error: 0.0163 - val_recall_20: 0.9730 - val_precision_20: 0.9730 - val_acc: 0.9730 - val_categorical_true_positives: 1044.0000
# Epoch 116/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.3004 - mean_squared_error: 0.0091 - recall_20: 0.9819 - precision_20: 0.9819 - acc: 0.9819 - categorical_true_positives: 3142.0000 - val_loss: 0.4087 - val_mean_squared_error: 0.0169 - val_recall_20: 0.9720 - val_precision_20: 0.9729 - val_acc: 0.9730 - val_categorical_true_positives: 1044.0000
# Epoch 117/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2896 - mean_squared_error: 0.0080 - recall_20: 0.9850 - precision_20: 0.9850 - acc: 0.9850 - categorical_true_positives: 3152.0000 - val_loss: 0.3610 - val_mean_squared_error: 0.0142 - val_recall_20: 0.9758 - val_precision_20: 0.9758 - val_acc: 0.9758 - val_categorical_true_positives: 1047.0000
# Epoch 118/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2918 - mean_squared_error: 0.0075 - recall_20: 0.9844 - precision_20: 0.9844 - acc: 0.9844 - categorical_true_positives: 3150.0000 - val_loss: 0.7547 - val_mean_squared_error: 0.0270 - val_recall_20: 0.9562 - val_precision_20: 0.9562 - val_acc: 0.9562 - val_categorical_true_positives: 1026.0000
# Epoch 119/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2984 - mean_squared_error: 0.0076 - recall_20: 0.9828 - precision_20: 0.9831 - acc: 0.9831 - categorical_true_positives: 3146.0000 - val_loss: 0.3828 - val_mean_squared_error: 0.0146 - val_recall_20: 0.9776 - val_precision_20: 0.9776 - val_acc: 0.9776 - val_categorical_true_positives: 1049.0000
# Epoch 120/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2971 - mean_squared_error: 0.0082 - recall_20: 0.9853 - precision_20: 0.9853 - acc: 0.9853 - categorical_true_positives: 3153.0000 - val_loss: 0.4182 - val_mean_squared_error: 0.0161 - val_recall_20: 0.9748 - val_precision_20: 0.9748 - val_acc: 0.9748 - val_categorical_true_positives: 1046.0000
# Epoch 121/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2944 - mean_squared_error: 0.0077 - recall_20: 0.9859 - precision_20: 0.9859 - acc: 0.9859 - categorical_true_positives: 3155.0000 - val_loss: 0.3048 - val_mean_squared_error: 0.0097 - val_recall_20: 0.9851 - val_precision_20: 0.9851 - val_acc: 0.9851 - val_categorical_true_positives: 1057.0000
# Epoch 122/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2829 - mean_squared_error: 0.0066 - recall_20: 0.9872 - precision_20: 0.9872 - acc: 0.9872 - categorical_true_positives: 3159.0000 - val_loss: 0.4990 - val_mean_squared_error: 0.0180 - val_recall_20: 0.9720 - val_precision_20: 0.9720 - val_acc: 0.9720 - val_categorical_true_positives: 1043.0000
# Epoch 123/200
# ...
# Epoch 146/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2773 - mean_squared_error: 0.0052 - recall_20: 0.9912 - precision_20: 0.9912 - acc: 0.9912 - categorical_true_positives: 3172.0000 - val_loss: 0.4053 - val_mean_squared_error: 0.0119 - val_recall_20: 0.9795 - val_precision_20: 0.9795 - val_acc: 0.9795 - val_categorical_true_positives: 1051.0000
# Epoch 147/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2605 - mean_squared_error: 0.0035 - recall_20: 0.9937 - precision_20: 0.9937 - acc: 0.9937 - categorical_true_positives: 3180.0000 - val_loss: 0.3725 - val_mean_squared_error: 0.0106 - val_recall_20: 0.9823 - val_precision_20: 0.9823 - val_acc: 0.9823 - val_categorical_true_positives: 1054.0000
# Epoch 148/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2525 - mean_squared_error: 0.0035 - recall_20: 0.9934 - precision_20: 0.9934 - acc: 0.9934 - categorical_true_positives: 3179.0000 - val_loss: 0.3830 - val_mean_squared_error: 0.0110 - val_recall_20: 0.9823 - val_precision_20: 0.9823 - val_acc: 0.9823 - val_categorical_true_positives: 1054.0000
# Epoch 149/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2394 - mean_squared_error: 0.0016 - recall_20: 0.9962 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.3303 - val_mean_squared_error: 0.0084 - val_recall_20: 0.9851 - val_precision_20: 0.9851 - val_acc: 0.9851 - val_categorical_true_positives: 1057.0000
# Epoch 150/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2508 - mean_squared_error: 0.0036 - recall_20: 0.9931 - precision_20: 0.9931 - acc: 0.9931 - categorical_true_positives: 3178.0000 - val_loss: 0.3850 - val_mean_squared_error: 0.0106 - val_recall_20: 0.9842 - val_precision_20: 0.9842 - val_acc: 0.9842 - val_categorical_true_positives: 1056.0000
# Epoch 151/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2518 - mean_squared_error: 0.0041 - recall_20: 0.9922 - precision_20: 0.9922 - acc: 0.9922 - categorical_true_positives: 3175.0000 - val_loss: 0.3870 - val_mean_squared_error: 0.0114 - val_recall_20: 0.9804 - val_precision_20: 0.9804 - val_acc: 0.9804 - val_categorical_true_positives: 1052.0000
# Epoch 152/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2590 - mean_squared_error: 0.0033 - recall_20: 0.9944 - precision_20: 0.9944 - acc: 0.9944 - categorical_true_positives: 3182.0000 - val_loss: 0.5508 - val_mean_squared_error: 0.0147 - val_recall_20: 0.9767 - val_precision_20: 0.9767 - val_acc: 0.9767 - val_categorical_true_positives: 1048.0000
# Epoch 153/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2567 - mean_squared_error: 0.0037 - recall_20: 0.9931 - precision_20: 0.9931 - acc: 0.9931 - categorical_true_positives: 3178.0000 - val_loss: 0.4067 - val_mean_squared_error: 0.0113 - val_recall_20: 0.9814 - val_precision_20: 0.9814 - val_acc: 0.9814 - val_categorical_true_positives: 1053.0000
# Epoch 154/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2436 - mean_squared_error: 0.0026 - recall_20: 0.9956 - precision_20: 0.9956 - acc: 0.9956 - categorical_true_positives: 3186.0000 - val_loss: 0.3795 - val_mean_squared_error: 0.0107 - val_recall_20: 0.9804 - val_precision_20: 0.9804 - val_acc: 0.9804 - val_categorical_true_positives: 1052.0000
# Epoch 155/200
# 100/100 [==============================] - 12s 124ms/step - loss: 0.2400 - mean_squared_error: 0.0028 - recall_20: 0.9941 - precision_20: 0.9941 - acc: 0.9941 - categorical_true_positives: 3181.0000 - val_loss: 0.3687 - val_mean_squared_error: 0.0091 - val_recall_20: 0.9851 - val_precision_20: 0.9851 - val_acc: 0.9851 - val_categorical_true_positives: 1057.0000
# Epoch 163/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2432 - mean_squared_error: 0.0029 - recall_20: 0.9950 - precision_20: 0.9950 - acc: 0.9950 - categorical_true_positives: 3184.0000 - val_loss: 0.3951 - val_mean_squared_error: 0.0104 - val_recall_20: 0.9823 - val_precision_20: 0.9823 - val_acc: 0.9823 - val_categorical_true_positives: 1054.0000
# Epoch 164/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2451 - mean_squared_error: 0.0029 - recall_20: 0.9950 - precision_20: 0.9950 - acc: 0.9950 - categorical_true_positives: 3184.0000 - val_loss: 0.3731 - val_mean_squared_error: 0.0091 - val_recall_20: 0.9832 - val_precision_20: 0.9832 - val_acc: 0.9832 - val_categorical_true_positives: 1055.0000
# Epoch 165/200
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2408 - mean_squared_error: 0.0029 - recall_20: 0.9950 - precision_20: 0.9950 - acc: 0.9950 - categorical_true_positives: 3184.0000 - val_loss: 0.3043 - val_mean_squared_error: 0.0069 - val_recall_20: 0.9860 - val_precision_20: 0.9860 - val_acc: 0.9860 - val_categorical_true_positives: 1058.0000
# Epoch 166/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.2434 - mean_squared_error: 0.0018 - recall_20: 0.9975 - precision_20: 0.9975 - acc: 0.9975 - categorical_true_positives: 3192.0000 - val_loss: 0.2833 - val_mean_squared_error: 0.0066 - val_recall_20: 0.9870 - val_precision_20: 0.9870 - val_acc: 0.9870 - val_categorical_true_positives: 1059.0000
# Epoch 167/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.2309 - mean_squared_error: 0.0024 - recall_20: 0.9947 - precision_20: 0.9947 - acc: 0.9947 - categorical_true_positives: 3183.0000 - val_loss: 0.2508 - val_mean_squared_error: 0.0046 - val_recall_20: 0.9916 - val_precision_20: 0.9916 - val_acc: 0.9916 - val_categorical_true_positives: 1064.0000
# Epoch 174/200
# 100/100 [==============================] - 12s 120ms/step - loss: 0.2316 - mean_squared_error: 0.0022 - recall_20: 0.9962 - precision_20: 0.9962 - acc: 0.9962 - categorical_true_positives: 3188.0000 - val_loss: 0.2612 - val_mean_squared_error: 0.0054 - val_recall_20: 0.9907 - val_precision_20: 0.9907 - val_acc: 0.9907 - val_categorical_true_positives: 1063.0000
# Epoch 175/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2303 - mean_squared_error: 0.0018 - recall_20: 0.9969 - precision_20: 0.9969 - acc: 0.9969 - categorical_true_positives: 3190.0000 - val_loss: 0.2282 - val_mean_squared_error: 0.0020 - val_recall_20: 0.9972 - val_precision_20: 0.9972 - val_acc: 0.9972 - val_categorical_true_positives: 1070.0000
# Epoch 176/200
# 100/100 [==============================] - 12s 122ms/step - loss: 0.2298 - mean_squared_error: 0.0018 - recall_20: 0.9969 - precision_20: 0.9969 - acc: 0.9969 - categorical_true_positives: 3190.0000 - val_loss: 0.2264 - val_mean_squared_error: 0.0021 - val_recall_20: 0.9953 - val_precision_20: 0.9953 - val_acc: 0.9953 - val_categorical_true_positives: 1068.0000
# Epoch 177/200
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2260 - mean_squared_error: 0.0016 - recall_20: 0.9975 - precision_20: 0.9975 - acc: 0.9975 - categorical_true_positives: 3192.0000 - val_loss: 0.2664 - val_mean_squared_error: 0.0047 - val_recall_20: 0.9916 - val_precision_20: 0.9916 - val_acc: 0.9916 - val_categorical_true_positives: 1064.0000
# Epoch 178/200
# 100/100 [==============================] - 11s 115ms/step - loss: 0.2263 - mean_squared_error: 0.0018 - recall_20: 0.9962 - precision_20: 0.9962 - acc: 0.9962 - categorical_true_positives: 3188.0000 - val_loss: 0.2501 - val_mean_squared_error: 0.0033 - val_recall_20: 0.9953 - val_precision_20: 0.9953 - val_acc: 0.9953 - val_categorical_true_positives: 1068.0000
# Epoch 179/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2225 - mean_squared_error: 0.0017 - recall_20: 0.9969 - precision_20: 0.9969 - acc: 0.9969 - categorical_true_positives: 3190.0000 - val_loss: 0.2592 - val_mean_squared_error: 0.0048 - val_recall_20: 0.9925 - val_precision_20: 0.9925 - val_acc: 0.9925 - val_categorical_true_positives: 1065.0000
# Epoch 180/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2251 - mean_squared_error: 0.0019 - recall_20: 0.9966 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.2339 - val_mean_squared_error: 0.0028 - val_recall_20: 0.9925 - val_precision_20: 0.9925 - val_acc: 0.9925 - val_categorical_true_positives: 1065.0000
# Epoch 181/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2221 - mean_squared_error: 0.0016 - recall_20: 0.9966 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.2727 - val_mean_squared_error: 0.0057 - val_recall_20: 0.9907 - val_precision_20: 0.9907 - val_acc: 0.9907 - val_categorical_true_positives: 1063.0000
# Epoch 182/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2286 - mean_squared_error: 0.0022 - recall_20: 0.9956 - precision_20: 0.9956 - acc: 0.9956 - categorical_true_positives: 3186.0000 - val_loss: 0.2401 - val_mean_squared_error: 0.0035 - val_recall_20: 0.9935 - val_precision_20: 0.9935 - val_acc: 0.9935 - val_categorical_true_positives: 1066.0000
# Epoch 183/200
# 100/100 [==============================] - 10s 95ms/step - loss: 0.2224 - mean_squared_error: 0.0015 - recall_20: 0.9978 - precision_20: 0.9978 - acc: 0.9978 - categorical_true_positives: 3193.0000 - val_loss: 0.2710 - val_mean_squared_error: 0.0050 - val_recall_20: 0.9916 - val_precision_20: 0.9916 - val_acc: 0.9916 - val_categorical_true_positives: 1064.0000
# Epoch 184/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2242 - mean_squared_error: 0.0025 - recall_20: 0.9947 - precision_20: 0.9947 - acc: 0.9947 - categorical_true_positives: 3183.0000 - val_loss: 0.2366 - val_mean_squared_error: 0.0031 - val_recall_20: 0.9935 - val_precision_20: 0.9935 - val_acc: 0.9935 - val_categorical_true_positives: 1066.0000
# Epoch 185/200
# 100/100 [==============================] - 10s 95ms/step - loss: 0.2188 - mean_squared_error: 0.0011 - recall_20: 0.9981 - precision_20: 0.9981 - acc: 0.9981 - categorical_true_positives: 3194.0000 - val_loss: 0.2493 - val_mean_squared_error: 0.0053 - val_recall_20: 0.9888 - val_precision_20: 0.9888 - val_acc: 0.9888 - val_categorical_true_positives: 1061.0000
# Epoch 186/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2234 - mean_squared_error: 8.2461e-04 - recall_20: 0.9984 - precision_20: 0.9984 - acc: 0.9984 - categorical_true_positives: 3195.0000 - val_loss: 0.2271 - val_mean_squared_error: 0.0022 - val_recall_20: 0.9953 - val_precision_20: 0.9953 - val_acc: 0.9953 - val_categorical_true_positives: 1068.0000
# Epoch 187/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2322 - mean_squared_error: 0.0028 - recall_20: 0.9950 - precision_20: 0.9950 - acc: 0.9950 - categorical_true_positives: 3184.0000 - val_loss: 0.2402 - val_mean_squared_error: 0.0043 - val_recall_20: 0.9916 - val_precision_20: 0.9916 - val_acc: 0.9916 - val_categorical_true_positives: 1064.0000
# Epoch 188/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2305 - mean_squared_error: 0.0026 - recall_20: 0.9953 - precision_20: 0.9953 - acc: 0.9953 - categorical_true_positives: 3185.0000 - val_loss: 0.5020 - val_mean_squared_error: 0.0121 - val_recall_20: 0.9814 - val_precision_20: 0.9814 - val_acc: 0.9814 - val_categorical_true_positives: 1053.0000
# Epoch 189/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2203 - mean_squared_error: 0.0017 - recall_20: 0.9966 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.2650 - val_mean_squared_error: 0.0041 - val_recall_20: 0.9916 - val_precision_20: 0.9916 - val_acc: 0.9916 - val_categorical_true_positives: 1064.0000
# Epoch 190/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2186 - mean_squared_error: 0.0014 - recall_20: 0.9981 - precision_20: 0.9981 - acc: 0.9981 - categorical_true_positives: 3194.0000 - val_loss: 0.4091 - val_mean_squared_error: 0.0098 - val_recall_20: 0.9842 - val_precision_20: 0.9842 - val_acc: 0.9842 - val_categorical_true_positives: 1056.0000
# Epoch 191/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2148 - mean_squared_error: 0.0015 - recall_20: 0.9978 - precision_20: 0.9978 - acc: 0.9978 - categorical_true_positives: 3193.0000 - val_loss: 0.3534 - val_mean_squared_error: 0.0089 - val_recall_20: 0.9851 - val_precision_20: 0.9851 - val_acc: 0.9851 - val_categorical_true_positives: 1057.0000
# Epoch 192/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2285 - mean_squared_error: 0.0021 - recall_20: 0.9969 - precision_20: 0.9969 - acc: 0.9969 - categorical_true_positives: 3190.0000 - val_loss: 0.4126 - val_mean_squared_error: 0.0096 - val_recall_20: 0.9851 - val_precision_20: 0.9851 - val_acc: 0.9851 - val_categorical_true_positives: 1057.0000
# Epoch 193/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2157 - mean_squared_error: 0.0018 - recall_20: 0.9966 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.2339 - val_mean_squared_error: 0.0044 - val_recall_20: 0.9925 - val_precision_20: 0.9925 - val_acc: 0.9925 - val_categorical_true_positives: 1065.0000
# Epoch 194/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2164 - mean_squared_error: 0.0017 - recall_20: 0.9966 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.3340 - val_mean_squared_error: 0.0079 - val_recall_20: 0.9860 - val_precision_20: 0.9860 - val_acc: 0.9860 - val_categorical_true_positives: 1058.0000
# Epoch 195/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2117 - mean_squared_error: 0.0012 - recall_20: 0.9975 - precision_20: 0.9975 - acc: 0.9975 - categorical_true_positives: 3192.0000 - val_loss: 0.2609 - val_mean_squared_error: 0.0063 - val_recall_20: 0.9888 - val_precision_20: 0.9888 - val_acc: 0.9888 - val_categorical_true_positives: 1061.0000
# Epoch 196/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2312 - mean_squared_error: 0.0023 - recall_20: 0.9956 - precision_20: 0.9956 - acc: 0.9956 - categorical_true_positives: 3186.0000 - val_loss: 0.3288 - val_mean_squared_error: 0.0076 - val_recall_20: 0.9870 - val_precision_20: 0.9870 - val_acc: 0.9870 - val_categorical_true_positives: 1059.0000
# Epoch 197/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2301 - mean_squared_error: 0.0023 - recall_20: 0.9956 - precision_20: 0.9956 - acc: 0.9956 - categorical_true_positives: 3186.0000 - val_loss: 0.2422 - val_mean_squared_error: 0.0052 - val_recall_20: 0.9916 - val_precision_20: 0.9916 - val_acc: 0.9916 - val_categorical_true_positives: 1064.0000
# Epoch 198/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2196 - mean_squared_error: 0.0024 - recall_20: 0.9953 - precision_20: 0.9953 - acc: 0.9953 - categorical_true_positives: 3185.0000 - val_loss: 0.3881 - val_mean_squared_error: 0.0092 - val_recall_20: 0.9860 - val_precision_20: 0.9860 - val_acc: 0.9860 - val_categorical_true_positives: 1058.0000
# Epoch 199/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2168 - mean_squared_error: 0.0019 - recall_20: 0.9966 - precision_20: 0.9966 - acc: 0.9966 - categorical_true_positives: 3189.0000 - val_loss: 0.2914 - val_mean_squared_error: 0.0063 - val_recall_20: 0.9897 - val_precision_20: 0.9897 - val_acc: 0.9897 - val_categorical_true_positives: 1062.0000
# Epoch 200/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2068 - mean_squared_error: 9.9372e-04 - recall_20: 0.9981 - precision_20: 0.9981 - acc: 0.9981 - categorical_true_positives: 3194.0000 - val_loss: 0.2397 - val_mean_squared_error: 0.0035 - val_recall_20: 0.9944 - val_precision_20: 0.9944 - val_acc: 0.9944 - val_categorical_true_positives: 1067.0000

# %%
result = build_triplet.predict(X_val)
preds_raw = np.argmax(result, axis=1)
preds = K.one_hot(preds_raw, nb_classes+1)

print("\nTrue positives per classes:")
for i in range(nb_classes+1):
    m = tf.keras.metrics.TruePositives(name='tp')    
    m.update_state(labels_val[:, i], preds[:, i])
    print("Class {} true positives: {}".format(i, m.result()))
    
r = tf.keras.metrics.Recall()
r.update_state(labels_val, preds)
r.result().numpy()
print('Recall ' + str(r.result()))

p = tf.keras.metrics.Precision()
p.update_state(labels_val, preds)
p.result().numpy()
print('Precision ' + str(p.result()))

f1 = 2*((p.result()*r.result())/(p.result()+r.result()+K.epsilon()))
print('F1 ' + str(f1))

import statistics
acc = statistics.mean(history.history['val_acc']) 
print('accuracy ' + str(acc))

# %% [markdown]
# ### Plotting

# %%
import pickle

with open(os.path.abspath(os.path.join('../../results/6/')), 'wb') as file_pi:
     pickle.dump(history.history, file_pi)

# %%
print('hi')

# %%
history_retrieve = pickle.load(open(os.path.abspath(os.path.join('../../results/6/')), "rb"))

# %%
# summarize history for accuracy
plt.plot(history_retrieve['acc'])
plt.plot(history_retrieve['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history_retrieve['loss'])
plt.plot(history_retrieve['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
